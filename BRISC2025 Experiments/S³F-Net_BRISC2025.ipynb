# %% [markdown]
# # **Spatial-Spectral Summarizer Fusion Network (S³F-Net)**

# %% [markdown]
# This notebook contains the full implementation of **S³F-Net** on the BRISC 2025 (Brain MRI Segmentation and Classification) dataset. We use the **SpectraNet-1** variant as the spectral encoder here, and use a powerful **Bilinear Fusion** to fuse the two branches (Spatial & Spectral). The full architecture is customizable, feel free to do so. Edit the file paths according to your setup.

# %% [markdown]
# ## **Data Preparation**

# %%
# ==============================================================================
# BLOCK 1: SETUP, IMPORTS AND DATA LOADING (FOR BRISC2025)
# ==============================================================================
import os
import cv2
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, callbacks
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score, cohen_kappa_score, matthews_corrcoef, roc_auc_score, roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle
import matplotlib.pyplot as plt
import seaborn as sns

# --- Setup ---
print("--- Mounting Google Drive ---")
drive.mount('/content/drive')

# --- Configuration ---
IMG_SIZE = (256, 256)
BATCH_SIZE = 16
EPOCHS = 200
RANDOM_STATE = 42

# --- Paths ---
DATASET_PATH = "/content/drive/MyDrive/Medical Image Segmentation/BRISC 2025 Dataset/classification_task"
TRAIN_PATH = os.path.join(DATASET_PATH, "train")
TEST_PATH = os.path.join(DATASET_PATH, "test")
SAVE_FOLDER = "/content/drive/MyDrive/S3F_Net_Models"
os.makedirs(SAVE_FOLDER, exist_ok=True)
CLASSIFIER_MODEL_PATH = os.path.join(SAVE_FOLDER, "Bilinear_S3f_net_SN1_BRISC.keras")

# %%
# ==============================================================================
# BLOCK 2: DATA LOADING AND PREPROCESSING FOR BRISC2025
# ==============================================================================
def load_data_from_folders(folder_path):
    """
    Loads images and labels from a folder structured with pre-defined class subdirectories (The kind we have for BRISC2025).
    (e.g., .../train/glioma/, .../train/meningioma/, etc.)
    """
    images, labels = [], []
    # Sorting the class names to ensure consistent mapping (e.g., glioma is always 0)
    class_names = sorted(os.listdir(folder_path))
    class_map = {name: i for i, name in enumerate(class_names)}

    print(f"Loading data from: {folder_path}")
    print(f"Found classes: {class_names} -> Mapped to: {class_map}")

    for class_name in class_names:
        class_path = os.path.join(folder_path, class_name)
        if not os.path.isdir(class_path): continue

        for filename in os.listdir(class_path):
            img_path = os.path.join(class_path, filename)
            try:
                img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
                if img is None: continue
                img = cv2.resize(img, IMG_SIZE, interpolation=cv2.INTER_AREA)
                img = img.astype('float32') / 255.0
                images.append(img[..., np.newaxis])
                labels.append(class_map[class_name])
            except Exception as e:
                print(f"Error loading {img_path}: {e}")
                continue

    # Shuffling the data to ensure randomness
    indices = np.arange(len(images))
    np.random.shuffle(indices)
    images = np.array(images)[indices]
    labels = np.array(labels)[indices]

    return images, labels, class_names

# --- Loading Data from Train and Test Folders ---
try:
    X_train, y_train, CLASS_NAMES = load_data_from_folders(TRAIN_PATH)
    X_test, y_test, _ = load_data_from_folders(TEST_PATH)

    print(f"\nTraining data loaded: {len(X_train)} samples")
    print(f"Test data loaded: {len(X_test)} samples")

    # Calculating class weights for handling any imbalance in the training set
    class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
    class_weights_dict = dict(enumerate(class_weights))
    print(f"\nCalculated class weights: {class_weights_dict}")

except Exception as e:
    print(f"Failed to load dataset: {e}")
    exit()
# Out:
# Loading data from: /content/drive/MyDrive/Medical Image Segmentation/BRISC 2025 Dataset/classification_task/train
# Found classes: ['glioma', 'meningioma', 'no_tumor', 'pituitary'] -> Mapped to: {'glioma': 0, 'meningioma': 1, 'no_tumor': 2, 'pituitary': 3}
# Loading data from: /content/drive/MyDrive/Medical Image Segmentation/BRISC 2025 Dataset/classification_task/test
# Found classes: ['glioma', 'meningioma', 'no_tumor', 'pituitary'] -> Mapped to: {'glioma': 0, 'meningioma': 1, 'no_tumor': 2, 'pituitary': 3}
#
# Training data loaded: 5000 samples
# Test data loaded: 1010 samples
#
# Calculated class weights: {0: np.float64(1.0897994768962511), 1: np.float64(0.9405568096313017), 2: np.float64(1.1715089034676665), 3: np.float64(0.8579272477693891)}

# %% [markdown]
# ## **S³F-Net (Bilinear-Fusion SN1 Variant) Model Building**

# %%
# ==============================================================================
# BLOCK 3: MODEL ARCHITECTURE (BILINEAR FUSION FOR BRISC2025)
# ==============================================================================
# This block defines the S³F-Net with SpectraNet-1 + Bilinear Fusion

# --- Custom SpectralFilter Layer & Encoders ---
class SpectralFilterLayer(layers.Layer):
    def __init__(self, filters, **kwargs): super().__init__(**kwargs); self.filters = filters
    def build(self, input_shape):
        _, h, w, c = input_shape
        fft_shape = (h, w // 2 + 1)
        self.real_weights = self.add_weight(name='real_weights', shape=(c, self.filters, *fft_shape), initializer='glorot_uniform')
        self.imag_weights = self.add_weight(name='imag_weights', shape=(c, self.filters, *fft_shape), initializer='glorot_uniform')
        self.bias = self.add_weight(name='bias', shape=(self.filters,), initializer='zeros')
    def call(self, inputs):
        inputs_p = tf.transpose(inputs, [0, 3, 1, 2])
        inputs_fft = tf.signal.rfft2d(inputs_p)
        kernel_fft = tf.complex(self.real_weights, self.imag_weights)
        output_fft = tf.einsum('bchw,cfhw->bfhw', inputs_fft, kernel_fft)
        output_s = tf.signal.irfft2d(output_fft)
        output_p = tf.transpose(output_s, [0, 2, 3, 1])
        return output_p + self.bias
    def get_config(self):
        config = super().get_config()
        config.update({"filters": self.filters})
        return config

class BilinearFusion(layers.Layer):
    """Performs a full bilinear fusion with normalization."""
    def call(self, inputs):
        spatial_vector, spectral_vector = inputs
        spatial_reshaped = tf.expand_dims(spatial_vector, axis=-1)
        spectral_reshaped = tf.expand_dims(spectral_vector, axis=-1)
        outer_product = tf.matmul(spatial_reshaped, spectral_reshaped, transpose_b=True)
        bilinear_vector = layers.Flatten()(outer_product)
        bilinear_vector = tf.sign(bilinear_vector) * tf.sqrt(tf.abs(bilinear_vector) + 1e-5)
        bilinear_vector = tf.nn.l2_normalize(bilinear_vector, axis=-1)
        return bilinear_vector
    def compute_output_shape(self, input_shape):
        spatial_shape, spectral_shape = input_shape
        return (spatial_shape[0], spatial_shape[1] * spectral_shape[1])

def build_spatial_encoder(inputs):
    x = inputs
    x = layers.Conv2D(32, 3, padding='same', activation='relu')(x)
    x = layers.Conv2D(32, 3, padding='same')(x); x = layers.BatchNormalization()(x); x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D(2)(x)
    x = layers.Dropout(0.2)(x)
    x = layers.Conv2D(64, 3, padding='same', activation='relu')(x)
    x = layers.Conv2D(64, 3, padding='same')(x); x = layers.BatchNormalization()(x); x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D(2)(x)
    x = layers.Dropout(0.3)(x)
    x = layers.Conv2D(128, 3, padding='same', activation='relu')(x)
    x = layers.Conv2D(128, 3, padding='same')(x); x = layers.BatchNormalization()(x); x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D(2)(x)
    x = layers.Dropout(0.4)(x)
    x = layers.Conv2D(256, 3, padding='same', activation='relu')(x)
    x = layers.Conv2D(256, 3, padding='same')(x); x = layers.BatchNormalization()(x); x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D(2)(x)
    x = layers.Dropout(0.4)(x)
    return x

def depthwise_sep_block(x, filters, kernel_size=3, strides=1):
    x = layers.DepthwiseConv2D(kernel_size, strides=strides, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = layers.Conv2D(filters, 1, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    return x

def build_spectral_summary_branch(inputs):
    x = SpectralFilterLayer(32)(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = depthwise_sep_block(x, 64)
    x = layers.MaxPooling2D(2)(x)

    x = depthwise_sep_block(x, 128)
    x = layers.MaxPooling2D(2)(x)

    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(16, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.1875)(x)
    x = layers.Dense(4, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.3125)(x)

    return x

# --- S³F-Net Model Builder with Bilinear Fusion ---
def build_s3f_net_bilinear(input_shape, num_classes):
    """Builds the S³F-Net with Bilinear fusion for classification."""
    inputs = layers.Input(input_shape)

    # --- Tower 1: Deep Spatial Branch ---
    spatial_features = build_spatial_encoder(inputs)
    spatial_vector_raw = layers.GlobalAveragePooling2D()(spatial_features)
    spatial_refined = layers.Dense(512, activation='relu')(spatial_vector_raw)
    spatial_refined = layers.BatchNormalization()(spatial_refined)
    spatial_refined = layers.Dropout(0.5)(spatial_refined)

    # --- Tower 2: Spectral Summary Branch ---
    spectral_summary_vector = build_spectral_summary_branch(inputs)

    # --- Bilinear Fusion ---
    bilinear_vector = BilinearFusion()([spatial_refined, spectral_summary_vector])

    # Output Layer
    outputs = layers.Dense(num_classes, activation='softmax')(bilinear_vector)

    model = models.Model(inputs, outputs, name="S3F_Net_Bilinear")

    # Compiling with CE loss
    model.compile(optimizer=optimizers.Adam(0.0003),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

print("Bilinear Fusion S³F-Net model architecture is ready for BRISC2025.")
# Out:
# Bilinear Fusion S³F-Net model architecture is ready for BRISC2025.

# %% [markdown]
# ## **Model Training**

# %%
# ======================================
# BLOCK 4: CUSTOM CALLBACK AND TRAINING
# ======================================
from sklearn.metrics import f1_score

# --- Custom F1 Score Callback to use 'weighted' average ---
class F1ScoreCallback(callbacks.Callback):
    def __init__(self, validation_data, filepath, patience=25):
        super(F1ScoreCallback, self).__init__()
        self.validation_data = validation_data
        self.filepath = filepath
        self.patience = patience
        self.best_f1 = -1.0
        self.wait = 0
    def on_epoch_end(self, epoch, logs=None):
        X_val, y_val = self.validation_data; y_pred_proba = self.model.predict(X_val, verbose=0)
        y_pred = np.argmax(y_pred_proba, axis=1)
        weighted_f1 = f1_score(y_val, y_pred, average='weighted', zero_division=0)
        logs['val_f1_weighted'] = weighted_f1
        print(f" - val_f1_weighted: {weighted_f1:.4f}", end="")
        if weighted_f1 > self.best_f1:
            print(f" (New best F1, saving model to {self.filepath})")
            self.best_f1 = weighted_f1
            self.model.save(self.filepath)
            self.wait = 0
        else:
            print()
            self.wait += 1
            if self.wait >= self.patience:
                print("Early stopping triggered based on weighted F1-score.")
                self.model.stop_training = True

# --- Defining the model path ---
CLASSIFIER_MODEL_PATH = os.path.join(SAVE_FOLDER, "Bilinear_S3f_net_SN1_BRISC.keras")

# --- Building the Model ---
print("\n--- Building Bilinear Fusion S³F-Net ---")
classifier_model = build_s3f_net_bilinear(X_train.shape[1:], num_classes=len(CLASS_NAMES))
classifier_model.summary()

# --- Callbacks ---
f1_callback = F1ScoreCallback(validation_data=(X_test, y_test),
                              filepath=CLASSIFIER_MODEL_PATH,
                              patience=40)
reduce_lr = callbacks.ReduceLROnPlateau(monitor='val_loss',
                                        factor=0.2,
                                        patience=20,
                                        min_lr=1e-6,
                                        verbose=1)

# --- Training the Model ---
print("\n--- Training Bilinear Fusion S³F-Net ---")
history = classifier_model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    class_weight=class_weights_dict,
    callbacks=[f1_callback, reduce_lr]
)

print("\n--- Training Finished ---")
# Out:
# --- Building Final Bilinear Fusion S²F-Net for BRISC2025 ---
# Model: "S2F_Net_Bilinear_Final"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 256, 256,  │        320 │ input_layer_1[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 256, 256,  │      9,248 │ conv2d_10[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 128, 128,  │          0 │ activation_4[0][… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spectral_conv_laye… │ (None, 256, 256,  │  2,113,568 │ input_layer_1[0]… │
# │ (SpectralConvLayer) │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 128, 128,  │          0 │ max_pooling2d_6[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ spectral_conv_la… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 128, 128,  │     18,496 │ dropout_7[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 128, 128,  │     36,928 │ conv2d_12[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_2  │ (None, 256, 256,  │        288 │ re_lu_5[0][0]     │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 64, 64,    │          0 │ activation_5[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 256, 256,  │      2,048 │ re_lu_6[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 64, 64,    │          0 │ max_pooling2d_7[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 64, 64,    │     73,856 │ dropout_8[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 64, 64,    │    147,584 │ conv2d_14[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_10    │ (None, 128, 128,  │          0 │ re_lu_7[0][0]     │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_3  │ (None, 128, 128,  │        576 │ max_pooling2d_10… │
# │ (DepthwiseConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_8     │ (None, 32, 32,    │          0 │ activation_6[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 32, 32,    │          0 │ max_pooling2d_8[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 128, 128,  │      8,192 │ re_lu_8[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 32, 32,    │    295,168 │ dropout_9[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 32, 32,    │    590,080 │ conv2d_16[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_11    │ (None, 64, 64,    │          0 │ re_lu_9[0][0]     │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ max_pooling2d_11… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_9     │ (None, 16, 16,    │          0 │ activation_7[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 16)        │      2,064 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 16, 16,    │          0 │ max_pooling2d_9[… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16)        │         64 │ dense_3[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ dropout_10[0][0]  │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, 16)        │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc_spatial (Dense)  │ (None, 512)       │    131,584 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 4)         │         68 │ dropout_12[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ fc_spatial[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4)         │         16 │ dense_4[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 512)       │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, 4)         │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bilinear_fusion_1   │ (None, 2048)      │          0 │ dropout_11[0][0], │
# │ (BilinearFusion)    │                   │            │ dropout_13[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 4)         │      8,196 │ bilinear_fusion_… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,443,592 (13.14 MB)
#  Trainable params: 3,440,928 (13.13 MB)
#  Non-trainable params: 2,664 (10.41 KB)
# --- Training on BRISC2025 (Monitoring Weighted F1) ---
# Epoch 1/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.4624 - loss: 1.3250 - val_f1_weighted: 0.1443 (New best F1, saving model to /content/drive/MyDrive/S2F_Net_Models/final_bilinear_s2f_net_BRISC.keras)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 87s 167ms/step - accuracy: 0.4626 - loss: 1.3248 - val_accuracy: 0.3069 - val_loss: 1.3548 - val_f1_weighted: 0.1443 - learning_rate: 3.0000e-04
# Epoch 2/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6486 - loss: 1.0847 - val_f1_weighted: 0.3533 (New best F1, saving model to /content/drive/MyDrive/S2F_Net_Models/final_bilinear_s2f_net_BRISC.keras)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 40ms/step - accuracy: 0.6487 - loss: 1.0845 - val_accuracy: 0.4376 - val_loss: 1.1890 - val_f1_weighted: 0.3533 - learning_rate: 3.0000e-04
# Epoch 3/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7325 - loss: 0.8722 - val_f1_weighted: 0.3643 (New best F1, saving model to /content/drive/MyDrive/S2F_Net_Models/final_bilinear_s2f_net_BRISC.keras)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 40ms/step - accuracy: 0.7325 - loss: 0.8721 - val_accuracy: 0.4812 - val_loss: 1.3768 - val_f1_weighted: 0.3643 - learning_rate: 3.0000e-04
# Epoch 4/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7638 - loss: 0.7486 - val_f1_weighted: 0.1590
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.7638 - loss: 0.7485 - val_accuracy: 0.2723 - val_loss: 2.9409 - val_f1_weighted: 0.1590 - learning_rate: 3.0000e-04
# Epoch 5/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7913 - loss: 0.6768 - val_f1_weighted: 0.4343 (New best F1, saving model to /content/drive/MyDrive/S2F_Net_Models/final_bilinear_s2f_net_BRISC.keras)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 40ms/step - accuracy: 0.7913 - loss: 0.6767 - val_accuracy: 0.4683 - val_loss: 1.7537 - val_f1_weighted: 0.4343 - learning_rate: 3.0000e-04
# Epoch 6/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7906 - loss: 0.6429 - val_f1_weighted: 0.4837 (New best F1, saving model to /content/drive/MyDrive/S2F_Net_Models/final_bilinear_s2f_net_BRISC.keras)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 40ms/step - accuracy: 0.7906 - loss: 0.6430 - val_accuracy: 0.5139 - val_loss: 1.0817 - val_f1_weighted: 0.4837 - learning_rate: 3.0000e-04
# Epoch 7/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7999 - loss: 0.6275 - val_f1_weighted: 0.1544
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.7999 - loss: 0.6274 - val_accuracy: 0.3119 - val_loss: 2.2609 - val_f1_weighted: 0.1544 - learning_rate: 3.0000e-04
# Epoch 8/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8138 - loss: 0.5680 - val_f1_weighted: 0.1861
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.8138 - loss: 0.5679 - val_accuracy: 0.2535 - val_loss: 2.7339 - val_f1_weighted: 0.1861 - learning_rate: 3.0000e-04
# Epoch 9/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8298 - loss: 0.5268 - val_f1_weighted: 0.5121 (New best F1, saving model to /content/drive/MyDrive/S2F_Net_Models/final_bilinear_s2f_net_BRISC.keras)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.8298 - loss: 0.5267 - val_accuracy: 0.5931 - val_loss: 1.6100 - val_f1_weighted: 0.5121 - learning_rate: 3.0000e-04
# Epoch 10/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8405 - loss: 0.4900 - val_f1_weighted: 0.5112
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.8405 - loss: 0.4899 - val_accuracy: 0.5139 - val_loss: 1.7968 - val_f1_weighted: 0.5112 - learning_rate: 3.0000e-04
# Epoch 11/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8598 - loss: 0.4541 - val_f1_weighted: 0.4526
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.8598 - loss: 0.4541 - val_accuracy: 0.4891 - val_loss: 2.6725 - val_f1_weighted: 0.4526 - learning_rate: 3.0000e-04
# Epoch 12/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8602 - loss: 0.4237 - val_f1_weighted: 0.4465
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.8602 - loss: 0.4237 - val_accuracy: 0.5069 - val_loss: 1.4534 - val_f1_weighted: 0.4465 - learning_rate: 3.0000e-04
# Epoch 13/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8717 - loss: 0.4086 - val_f1_weighted: 0.7619 (New best F1, saving model to /content/drive/MyDrive/S2F_Net_Models/final_bilinear_s2f_net_BRISC.keras)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.8717 - loss: 0.4085 - val_accuracy: 0.7802 - val_loss: 0.6949 - val_f1_weighted: 0.7619 - learning_rate: 3.0000e-04
# Epoch 14/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8924 - loss: 0.3514 - val_f1_weighted: 0.4314
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.8924 - loss: 0.3514 - val_accuracy: 0.5069 - val_loss: 1.6977 - val_f1_weighted: 0.4314 - learning_rate: 3.0000e-04
# Epoch 15/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8992 - loss: 0.3374 - val_f1_weighted: 0.7627 (New best F1, saving model to /content/drive/MyDrive/S2F_Net_Models/final_bilinear_s2f_net_BRISC.keras)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.8992 - loss: 0.3373 - val_accuracy: 0.7624 - val_loss: 0.7912 - val_f1_weighted: 0.7627 - learning_rate: 3.0000e-04
# Epoch 16/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9055 - loss: 0.3175 - val_f1_weighted: 0.8054 (New best F1, saving model to /content/drive/MyDrive/S2F_Net_Models/final_bilinear_s2f_net_BRISC.keras)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.9055 - loss: 0.3175 - val_accuracy: 0.8040 - val_loss: 0.8122 - val_f1_weighted: 0.8054 - learning_rate: 3.0000e-04
# Epoch 17/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9021 - loss: 0.3172 - val_f1_weighted: 0.3286
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9021 - loss: 0.3173 - val_accuracy: 0.3812 - val_loss: 3.9135 - val_f1_weighted: 0.3286 - learning_rate: 3.0000e-04
# Epoch 18/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9002 - loss: 0.3234 - val_f1_weighted: 0.3371
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9002 - loss: 0.3234 - val_accuracy: 0.3980 - val_loss: 3.1295 - val_f1_weighted: 0.3371 - learning_rate: 3.0000e-04
# Epoch 19/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9022 - loss: 0.3117 - val_f1_weighted: 0.5364
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9022 - loss: 0.3117 - val_accuracy: 0.5950 - val_loss: 1.5122 - val_f1_weighted: 0.5364 - learning_rate: 3.0000e-04
# Epoch 20/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9194 - loss: 0.2903 - val_f1_weighted: 0.7735
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9193 - loss: 0.2903 - val_accuracy: 0.7911 - val_loss: 0.7043 - val_f1_weighted: 0.7735 - learning_rate: 3.0000e-04
# Epoch 21/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9212 - loss: 0.2621 - val_f1_weighted: 0.4818
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9212 - loss: 0.2621 - val_accuracy: 0.5366 - val_loss: 1.9917 - val_f1_weighted: 0.4818 - learning_rate: 3.0000e-04
# Epoch 22/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9282 - loss: 0.2260 - val_f1_weighted: 0.6239
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9282 - loss: 0.2260 - val_accuracy: 0.6257 - val_loss: 2.1510 - val_f1_weighted: 0.6239 - learning_rate: 3.0000e-04
# Epoch 23/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9257 - loss: 0.2444 - val_f1_weighted: 0.3477
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9257 - loss: 0.2444 - val_accuracy: 0.4762 - val_loss: 2.6752 - val_f1_weighted: 0.3477 - learning_rate: 3.0000e-04
# Epoch 24/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9335 - loss: 0.2150 - val_f1_weighted: 0.7949
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9335 - loss: 0.2150 - val_accuracy: 0.8040 - val_loss: 0.6209 - val_f1_weighted: 0.7949 - learning_rate: 3.0000e-04
# Epoch 25/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9343 - loss: 0.2142 - val_f1_weighted: 0.9157 (New best F1, saving model to /content/drive/MyDrive/S2F_Net_Models/final_bilinear_s2f_net_BRISC.keras)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.9343 - loss: 0.2142 - val_accuracy: 0.9158 - val_loss: 0.2790 - val_f1_weighted: 0.9157 - learning_rate: 3.0000e-04
# Epoch 26/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9312 - loss: 0.2080 - val_f1_weighted: 0.5615
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9312 - loss: 0.2080 - val_accuracy: 0.6228 - val_loss: 1.6423 - val_f1_weighted: 0.5615 - learning_rate: 3.0000e-04
# Epoch 27/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9413 - loss: 0.1966 - val_f1_weighted: 0.2361
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9413 - loss: 0.1966 - val_accuracy: 0.2980 - val_loss: 4.8702 - val_f1_weighted: 0.2361 - learning_rate: 3.0000e-04
# Epoch 28/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9489 - loss: 0.1689 - val_f1_weighted: 0.8504
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9488 - loss: 0.1690 - val_accuracy: 0.8535 - val_loss: 0.5403 - val_f1_weighted: 0.8504 - learning_rate: 3.0000e-04
# Epoch 29/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9554 - loss: 0.1592 - val_f1_weighted: 0.8802
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9554 - loss: 0.1592 - val_accuracy: 0.8832 - val_loss: 0.3925 - val_f1_weighted: 0.8802 - learning_rate: 3.0000e-04
# Epoch 30/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9534 - loss: 0.1557 - val_f1_weighted: 0.4770
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9534 - loss: 0.1557 - val_accuracy: 0.5693 - val_loss: 2.0484 - val_f1_weighted: 0.4770 - learning_rate: 3.0000e-04
# Epoch 31/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9581 - loss: 0.1483 - val_f1_weighted: 0.6246
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9581 - loss: 0.1483 - val_accuracy: 0.6980 - val_loss: 1.8428 - val_f1_weighted: 0.6246 - learning_rate: 3.0000e-04
# Epoch 32/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9564 - loss: 0.1519 - val_f1_weighted: 0.3917
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9564 - loss: 0.1519 - val_accuracy: 0.4515 - val_loss: 3.7488 - val_f1_weighted: 0.3917 - learning_rate: 3.0000e-04
# Epoch 33/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9523 - loss: 0.1594 - val_f1_weighted: 0.8844
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9523 - loss: 0.1594 - val_accuracy: 0.8861 - val_loss: 0.3973 - val_f1_weighted: 0.8844 - learning_rate: 3.0000e-04
# Epoch 34/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9473 - loss: 0.1667 - val_f1_weighted: 0.7846
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9473 - loss: 0.1667 - val_accuracy: 0.7931 - val_loss: 0.8416 - val_f1_weighted: 0.7846 - learning_rate: 3.0000e-04
# Epoch 35/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9635 - loss: 0.1235 - val_f1_weighted: 0.5304
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9635 - loss: 0.1235 - val_accuracy: 0.5525 - val_loss: 2.3069 - val_f1_weighted: 0.5304 - learning_rate: 3.0000e-04
# Epoch 36/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9616 - loss: 0.1333 - val_f1_weighted: 0.6633
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9616 - loss: 0.1333 - val_accuracy: 0.6881 - val_loss: 1.5803 - val_f1_weighted: 0.6633 - learning_rate: 3.0000e-04
# Epoch 37/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9442 - loss: 0.1979 - val_f1_weighted: 0.8086
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9442 - loss: 0.1978 - val_accuracy: 0.8109 - val_loss: 0.5759 - val_f1_weighted: 0.8086 - learning_rate: 3.0000e-04
# Epoch 38/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9542 - loss: 0.1666 - val_f1_weighted: 0.8614
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9542 - loss: 0.1666 - val_accuracy: 0.8663 - val_loss: 0.4507 - val_f1_weighted: 0.8614 - learning_rate: 3.0000e-04
# Epoch 39/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9670 - loss: 0.1271 - val_f1_weighted: 0.5211
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9670 - loss: 0.1271 - val_accuracy: 0.5584 - val_loss: 1.8651 - val_f1_weighted: 0.5211 - learning_rate: 3.0000e-04
# Epoch 40/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9686 - loss: 0.1112 - val_f1_weighted: 0.5123
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9686 - loss: 0.1112 - val_accuracy: 0.5475 - val_loss: 1.6602 - val_f1_weighted: 0.5123 - learning_rate: 3.0000e-04
# Epoch 41/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9594 - loss: 0.1383 - val_f1_weighted: 0.8959
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9594 - loss: 0.1383 - val_accuracy: 0.9000 - val_loss: 0.3407 - val_f1_weighted: 0.8959 - learning_rate: 3.0000e-04
# Epoch 42/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9730 - loss: 0.1052 - val_f1_weighted: 0.6172
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9729 - loss: 0.1053 - val_accuracy: 0.7149 - val_loss: 1.3952 - val_f1_weighted: 0.6172 - learning_rate: 3.0000e-04
# Epoch 43/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9609 - loss: 0.1458 - val_f1_weighted: 0.7026
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9609 - loss: 0.1458 - val_accuracy: 0.7257 - val_loss: 1.2021 - val_f1_weighted: 0.7026 - learning_rate: 3.0000e-04
# Epoch 44/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9645 - loss: 0.1147 - val_f1_weighted: 0.7798
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9645 - loss: 0.1147 - val_accuracy: 0.7861 - val_loss: 0.7750 - val_f1_weighted: 0.7798 - learning_rate: 3.0000e-04
# Epoch 45/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9635 - loss: 0.1268 - val_f1_weighted: 0.9314 (New best F1, saving model to /content/drive/MyDrive/S2F_Net_Models/final_bilinear_s2f_net_BRISC.keras)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9635 - loss: 0.1268 - val_accuracy: 0.9317 - val_loss: 0.2248 - val_f1_weighted: 0.9314 - learning_rate: 3.0000e-04
# Epoch 46/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9620 - loss: 0.1267 - val_f1_weighted: 0.7189
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9620 - loss: 0.1267 - val_accuracy: 0.7426 - val_loss: 1.2496 - val_f1_weighted: 0.7189 - learning_rate: 3.0000e-04
# Epoch 47/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9654 - loss: 0.1065 - val_f1_weighted: 0.9376 (New best F1, saving model to /content/drive/MyDrive/S2F_Net_Models/final_bilinear_s2f_net_BRISC.keras)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9654 - loss: 0.1065 - val_accuracy: 0.9386 - val_loss: 0.2780 - val_f1_weighted: 0.9376 - learning_rate: 3.0000e-04
# Epoch 48/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9679 - loss: 0.1115 - val_f1_weighted: 0.5691
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9679 - loss: 0.1115 - val_accuracy: 0.6257 - val_loss: 1.9300 - val_f1_weighted: 0.5691 - learning_rate: 3.0000e-04
# Epoch 49/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9713 - loss: 0.0931 - val_f1_weighted: 0.7561
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9712 - loss: 0.0931 - val_accuracy: 0.7911 - val_loss: 1.2472 - val_f1_weighted: 0.7561 - learning_rate: 3.0000e-04
# Epoch 50/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9739 - loss: 0.0866 - val_f1_weighted: 0.6195
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9739 - loss: 0.0866 - val_accuracy: 0.7149 - val_loss: 1.3845 - val_f1_weighted: 0.6195 - learning_rate: 3.0000e-04
# Epoch 51/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9642 - loss: 0.1189 - val_f1_weighted: 0.8301
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9642 - loss: 0.1189 - val_accuracy: 0.8455 - val_loss: 0.7975 - val_f1_weighted: 0.8301 - learning_rate: 3.0000e-04
# Epoch 52/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9714 - loss: 0.0943 - val_f1_weighted: 0.7586
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9714 - loss: 0.0944 - val_accuracy: 0.7832 - val_loss: 0.6747 - val_f1_weighted: 0.7586 - learning_rate: 3.0000e-04
# Epoch 53/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9779 - loss: 0.0778 - val_f1_weighted: 0.9192
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9779 - loss: 0.0778 - val_accuracy: 0.9208 - val_loss: 0.3693 - val_f1_weighted: 0.9192 - learning_rate: 3.0000e-04
# Epoch 54/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9680 - loss: 0.0896 - val_f1_weighted: 0.9581 (New best F1, saving model to /content/drive/MyDrive/S2F_Net_Models/final_bilinear_s2f_net_BRISC.keras)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9680 - loss: 0.0896 - val_accuracy: 0.9584 - val_loss: 0.2007 - val_f1_weighted: 0.9581 - learning_rate: 3.0000e-04
# Epoch 55/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9691 - loss: 0.0982 - val_f1_weighted: 0.7069
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9691 - loss: 0.0981 - val_accuracy: 0.7683 - val_loss: 0.7064 - val_f1_weighted: 0.7069 - learning_rate: 3.0000e-04
# Epoch 56/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9715 - loss: 0.0847 - val_f1_weighted: 0.8962
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9715 - loss: 0.0847 - val_accuracy: 0.9010 - val_loss: 0.3526 - val_f1_weighted: 0.8962 - learning_rate: 3.0000e-04
# Epoch 57/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9731 - loss: 0.0909 - val_f1_weighted: 0.8943
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9731 - loss: 0.0910 - val_accuracy: 0.8980 - val_loss: 0.4012 - val_f1_weighted: 0.8943 - learning_rate: 3.0000e-04
# Epoch 58/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9684 - loss: 0.0992 - val_f1_weighted: 0.7904
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9684 - loss: 0.0992 - val_accuracy: 0.7921 - val_loss: 0.7907 - val_f1_weighted: 0.7904 - learning_rate: 3.0000e-04
# Epoch 59/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9707 - loss: 0.0882 - val_f1_weighted: 0.9633 (New best F1, saving model to /content/drive/MyDrive/S2F_Net_Models/final_bilinear_s2f_net_BRISC.keras)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 40ms/step - accuracy: 0.9707 - loss: 0.0882 - val_accuracy: 0.9634 - val_loss: 0.1378 - val_f1_weighted: 0.9633 - learning_rate: 3.0000e-04
# Epoch 60/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9720 - loss: 0.0863 - val_f1_weighted: 0.8087
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9720 - loss: 0.0863 - val_accuracy: 0.8050 - val_loss: 0.9803 - val_f1_weighted: 0.8087 - learning_rate: 3.0000e-04
# Epoch 61/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9680 - loss: 0.0966 - val_f1_weighted: 0.8054
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9680 - loss: 0.0966 - val_accuracy: 0.8168 - val_loss: 0.7006 - val_f1_weighted: 0.8054 - learning_rate: 3.0000e-04
# Epoch 62/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9682 - loss: 0.0965 - val_f1_weighted: 0.8572
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9682 - loss: 0.0965 - val_accuracy: 0.8574 - val_loss: 0.6071 - val_f1_weighted: 0.8572 - learning_rate: 3.0000e-04
# Epoch 63/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9730 - loss: 0.0867 - val_f1_weighted: 0.8668
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9730 - loss: 0.0868 - val_accuracy: 0.8634 - val_loss: 0.6768 - val_f1_weighted: 0.8668 - learning_rate: 3.0000e-04
# Epoch 64/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9619 - loss: 0.1063 - val_f1_weighted: 0.2570
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9619 - loss: 0.1063 - val_accuracy: 0.3416 - val_loss: 3.9084 - val_f1_weighted: 0.2570 - learning_rate: 3.0000e-04
# Epoch 65/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9728 - loss: 0.0866 - val_f1_weighted: 0.8536
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9728 - loss: 0.0866 - val_accuracy: 0.8505 - val_loss: 0.6745 - val_f1_weighted: 0.8536 - learning_rate: 3.0000e-04
# Epoch 66/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9692 - loss: 0.1004 - val_f1_weighted: 0.9602
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9692 - loss: 0.1004 - val_accuracy: 0.9604 - val_loss: 0.2171 - val_f1_weighted: 0.9602 - learning_rate: 3.0000e-04
# Epoch 67/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9707 - loss: 0.0816 - val_f1_weighted: 0.9663 (New best F1, saving model to /content/drive/MyDrive/S2F_Net_Models/final_bilinear_s2f_net_BRISC.keras)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.9707 - loss: 0.0817 - val_accuracy: 0.9663 - val_loss: 0.1203 - val_f1_weighted: 0.9663 - learning_rate: 3.0000e-04
# Epoch 68/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9750 - loss: 0.0780 - val_f1_weighted: 0.9583
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9750 - loss: 0.0780 - val_accuracy: 0.9584 - val_loss: 0.1588 - val_f1_weighted: 0.9583 - learning_rate: 3.0000e-04
# Epoch 69/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9843 - loss: 0.0648 - val_f1_weighted: 0.7691
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9843 - loss: 0.0648 - val_accuracy: 0.8010 - val_loss: 0.7487 - val_f1_weighted: 0.7691 - learning_rate: 3.0000e-04
# Epoch 70/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9711 - loss: 0.0879 - val_f1_weighted: 0.6301
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9711 - loss: 0.0879 - val_accuracy: 0.7059 - val_loss: 2.6300 - val_f1_weighted: 0.6301 - learning_rate: 3.0000e-04
# Epoch 71/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9797 - loss: 0.0663 - val_f1_weighted: 0.9366
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9797 - loss: 0.0663 - val_accuracy: 0.9376 - val_loss: 0.2892 - val_f1_weighted: 0.9366 - learning_rate: 3.0000e-04
# Epoch 72/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9784 - loss: 0.0708 - val_f1_weighted: 0.5559
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9784 - loss: 0.0709 - val_accuracy: 0.5782 - val_loss: 1.9446 - val_f1_weighted: 0.5559 - learning_rate: 3.0000e-04
# Epoch 73/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9702 - loss: 0.0922 - val_f1_weighted: 0.8185
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9702 - loss: 0.0922 - val_accuracy: 0.8277 - val_loss: 0.7056 - val_f1_weighted: 0.8185 - learning_rate: 3.0000e-04
# Epoch 74/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9707 - loss: 0.0884 - val_f1_weighted: 0.9461
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9707 - loss: 0.0883 - val_accuracy: 0.9465 - val_loss: 0.2715 - val_f1_weighted: 0.9461 - learning_rate: 3.0000e-04
# Epoch 75/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9740 - loss: 0.0708 - val_f1_weighted: 0.9712 (New best F1, saving model to /content/drive/MyDrive/S2F_Net_Models/final_bilinear_s2f_net_BRISC.keras)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.9740 - loss: 0.0707 - val_accuracy: 0.9713 - val_loss: 0.1671 - val_f1_weighted: 0.9712 - learning_rate: 3.0000e-04
# Epoch 76/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9796 - loss: 0.0576 - val_f1_weighted: 0.8519
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9796 - loss: 0.0576 - val_accuracy: 0.8495 - val_loss: 0.5767 - val_f1_weighted: 0.8519 - learning_rate: 3.0000e-04
# Epoch 77/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9787 - loss: 0.0693 - val_f1_weighted: 0.9712 (New best F1, saving model to /content/drive/MyDrive/S2F_Net_Models/final_bilinear_s2f_net_BRISC.keras)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.9787 - loss: 0.0693 - val_accuracy: 0.9713 - val_loss: 0.1329 - val_f1_weighted: 0.9712 - learning_rate: 3.0000e-04
# Epoch 78/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9732 - loss: 0.0749 - val_f1_weighted: 0.8653
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9732 - loss: 0.0749 - val_accuracy: 0.8683 - val_loss: 0.5501 - val_f1_weighted: 0.8653 - learning_rate: 3.0000e-04
# Epoch 79/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9777 - loss: 0.0665 - val_f1_weighted: 0.9545
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9777 - loss: 0.0665 - val_accuracy: 0.9545 - val_loss: 0.1929 - val_f1_weighted: 0.9545 - learning_rate: 3.0000e-04
# Epoch 80/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9830 - loss: 0.0484 - val_f1_weighted: 0.9604
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9830 - loss: 0.0485 - val_accuracy: 0.9604 - val_loss: 0.1635 - val_f1_weighted: 0.9604 - learning_rate: 3.0000e-04
# Epoch 81/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9864 - loss: 0.0461 - val_f1_weighted: 0.9673
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9864 - loss: 0.0461 - val_accuracy: 0.9673 - val_loss: 0.1540 - val_f1_weighted: 0.9673 - learning_rate: 3.0000e-04
# Epoch 82/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9768 - loss: 0.0620 - val_f1_weighted: 0.8565
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9768 - loss: 0.0620 - val_accuracy: 0.8545 - val_loss: 0.7228 - val_f1_weighted: 0.8565 - learning_rate: 3.0000e-04
# Epoch 83/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9815 - loss: 0.0521 - val_f1_weighted: 0.8836
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9815 - loss: 0.0521 - val_accuracy: 0.8901 - val_loss: 0.6094 - val_f1_weighted: 0.8836 - learning_rate: 3.0000e-04
# Epoch 84/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9818 - loss: 0.0496 - val_f1_weighted: 0.7713
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9818 - loss: 0.0496 - val_accuracy: 0.7733 - val_loss: 1.4503 - val_f1_weighted: 0.7713 - learning_rate: 3.0000e-04
# Epoch 85/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9823 - loss: 0.0697 - val_f1_weighted: 0.8177
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9822 - loss: 0.0697 - val_accuracy: 0.8267 - val_loss: 0.9013 - val_f1_weighted: 0.8177 - learning_rate: 3.0000e-04
# Epoch 86/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9760 - loss: 0.0700 - val_f1_weighted: 0.8029
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9760 - loss: 0.0700 - val_accuracy: 0.8050 - val_loss: 0.9578 - val_f1_weighted: 0.8029 - learning_rate: 3.0000e-04
# Epoch 87/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9836 - loss: 0.0542 - val_f1_weighted: 0.9595
#
# Epoch 87: ReduceLROnPlateau reducing learning rate to 6.000000284984708e-05.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9836 - loss: 0.0542 - val_accuracy: 0.9594 - val_loss: 0.2138 - val_f1_weighted: 0.9595 - learning_rate: 3.0000e-04
# Epoch 88/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9799 - loss: 0.0598 - val_f1_weighted: 0.9802 (New best F1, saving model to /content/drive/MyDrive/S2F_Net_Models/final_bilinear_s2f_net_BRISC.keras)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.9799 - loss: 0.0597 - val_accuracy: 0.9802 - val_loss: 0.1271 - val_f1_weighted: 0.9802 - learning_rate: 6.0000e-05
# Epoch 89/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9840 - loss: 0.0453 - val_f1_weighted: 0.9802
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9840 - loss: 0.0453 - val_accuracy: 0.9802 - val_loss: 0.1468 - val_f1_weighted: 0.9802 - learning_rate: 6.0000e-05
# Epoch 90/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9889 - loss: 0.0360 - val_f1_weighted: 0.9772
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9889 - loss: 0.0361 - val_accuracy: 0.9772 - val_loss: 0.1379 - val_f1_weighted: 0.9772 - learning_rate: 6.0000e-05
# Epoch 91/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9850 - loss: 0.0409 - val_f1_weighted: 0.9822 (New best F1, saving model to /content/drive/MyDrive/S2F_Net_Models/final_bilinear_s2f_net_BRISC.keras)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.9850 - loss: 0.0409 - val_accuracy: 0.9822 - val_loss: 0.1351 - val_f1_weighted: 0.9822 - learning_rate: 6.0000e-05
# Epoch 92/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9862 - loss: 0.0395 - val_f1_weighted: 0.9851 (New best F1, saving model to /content/drive/MyDrive/S2F_Net_Models/final_bilinear_s2f_net_BRISC.keras)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 40ms/step - accuracy: 0.9862 - loss: 0.0395 - val_accuracy: 0.9851 - val_loss: 0.1135 - val_f1_weighted: 0.9851 - learning_rate: 6.0000e-05
# Epoch 93/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9792 - loss: 0.0573 - val_f1_weighted: 0.9842
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9792 - loss: 0.0572 - val_accuracy: 0.9842 - val_loss: 0.1173 - val_f1_weighted: 0.9842 - learning_rate: 6.0000e-05
# Epoch 94/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9900 - loss: 0.0308 - val_f1_weighted: 0.9812
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9900 - loss: 0.0308 - val_accuracy: 0.9812 - val_loss: 0.1221 - val_f1_weighted: 0.9812 - learning_rate: 6.0000e-05
# Epoch 95/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9902 - loss: 0.0332 - val_f1_weighted: 0.9841
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9902 - loss: 0.0332 - val_accuracy: 0.9842 - val_loss: 0.1286 - val_f1_weighted: 0.9841 - learning_rate: 6.0000e-05
# Epoch 96/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9878 - loss: 0.0369 - val_f1_weighted: 0.9881 (New best F1, saving model to /content/drive/MyDrive/S2F_Net_Models/final_bilinear_s2f_net_BRISC.keras)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.9878 - loss: 0.0370 - val_accuracy: 0.9881 - val_loss: 0.1034 - val_f1_weighted: 0.9881 - learning_rate: 6.0000e-05
# Epoch 97/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9828 - loss: 0.0479 - val_f1_weighted: 0.9802
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9828 - loss: 0.0479 - val_accuracy: 0.9802 - val_loss: 0.1329 - val_f1_weighted: 0.9802 - learning_rate: 6.0000e-05
# Epoch 98/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9837 - loss: 0.0444 - val_f1_weighted: 0.9782
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9837 - loss: 0.0444 - val_accuracy: 0.9782 - val_loss: 0.1235 - val_f1_weighted: 0.9782 - learning_rate: 6.0000e-05
# Epoch 99/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0394 - val_f1_weighted: 0.9811
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9896 - loss: 0.0394 - val_accuracy: 0.9812 - val_loss: 0.1330 - val_f1_weighted: 0.9811 - learning_rate: 6.0000e-05
# Epoch 100/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9841 - loss: 0.0534 - val_f1_weighted: 0.9832
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9841 - loss: 0.0534 - val_accuracy: 0.9832 - val_loss: 0.1213 - val_f1_weighted: 0.9832 - learning_rate: 6.0000e-05
# Epoch 101/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9893 - loss: 0.0309 - val_f1_weighted: 0.9822
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9893 - loss: 0.0309 - val_accuracy: 0.9822 - val_loss: 0.1271 - val_f1_weighted: 0.9822 - learning_rate: 6.0000e-05
# Epoch 102/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9877 - loss: 0.0428 - val_f1_weighted: 0.9831
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9877 - loss: 0.0428 - val_accuracy: 0.9832 - val_loss: 0.1281 - val_f1_weighted: 0.9831 - learning_rate: 6.0000e-05
# Epoch 103/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9870 - loss: 0.0412 - val_f1_weighted: 0.9772
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9870 - loss: 0.0412 - val_accuracy: 0.9772 - val_loss: 0.1447 - val_f1_weighted: 0.9772 - learning_rate: 6.0000e-05
# Epoch 104/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9893 - loss: 0.0350 - val_f1_weighted: 0.9832
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9893 - loss: 0.0350 - val_accuracy: 0.9832 - val_loss: 0.1104 - val_f1_weighted: 0.9832 - learning_rate: 6.0000e-05
# Epoch 105/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9841 - loss: 0.0451 - val_f1_weighted: 0.9841
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9841 - loss: 0.0451 - val_accuracy: 0.9842 - val_loss: 0.1085 - val_f1_weighted: 0.9841 - learning_rate: 6.0000e-05
# Epoch 106/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9883 - loss: 0.0336 - val_f1_weighted: 0.9842
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9883 - loss: 0.0336 - val_accuracy: 0.9842 - val_loss: 0.1241 - val_f1_weighted: 0.9842 - learning_rate: 6.0000e-05
# Epoch 107/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9835 - loss: 0.0404 - val_f1_weighted: 0.9791
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9835 - loss: 0.0404 - val_accuracy: 0.9792 - val_loss: 0.1226 - val_f1_weighted: 0.9791 - learning_rate: 6.0000e-05
# Epoch 108/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9887 - loss: 0.0340 - val_f1_weighted: 0.9822
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9887 - loss: 0.0340 - val_accuracy: 0.9822 - val_loss: 0.1338 - val_f1_weighted: 0.9822 - learning_rate: 6.0000e-05
# Epoch 109/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9851 - loss: 0.0460 - val_f1_weighted: 0.9655
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9851 - loss: 0.0460 - val_accuracy: 0.9653 - val_loss: 0.1787 - val_f1_weighted: 0.9655 - learning_rate: 6.0000e-05
# Epoch 110/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9875 - loss: 0.0372 - val_f1_weighted: 0.9842
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9875 - loss: 0.0372 - val_accuracy: 0.9842 - val_loss: 0.1067 - val_f1_weighted: 0.9842 - learning_rate: 6.0000e-05
# Epoch 111/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9866 - loss: 0.0353 - val_f1_weighted: 0.9782
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9866 - loss: 0.0353 - val_accuracy: 0.9782 - val_loss: 0.1525 - val_f1_weighted: 0.9782 - learning_rate: 6.0000e-05
# Epoch 112/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9877 - loss: 0.0340 - val_f1_weighted: 0.9841
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9877 - loss: 0.0340 - val_accuracy: 0.9842 - val_loss: 0.1152 - val_f1_weighted: 0.9841 - learning_rate: 6.0000e-05
# Epoch 113/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9856 - loss: 0.0399 - val_f1_weighted: 0.9831
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9857 - loss: 0.0399 - val_accuracy: 0.9832 - val_loss: 0.1175 - val_f1_weighted: 0.9831 - learning_rate: 6.0000e-05
# Epoch 114/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9874 - loss: 0.0303 - val_f1_weighted: 0.9851
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9874 - loss: 0.0304 - val_accuracy: 0.9851 - val_loss: 0.1116 - val_f1_weighted: 0.9851 - learning_rate: 6.0000e-05
# Epoch 115/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9920 - loss: 0.0269 - val_f1_weighted: 0.9841
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9920 - loss: 0.0269 - val_accuracy: 0.9842 - val_loss: 0.1096 - val_f1_weighted: 0.9841 - learning_rate: 6.0000e-05
# Epoch 116/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9889 - loss: 0.0298 - val_f1_weighted: 0.9742
#
# Epoch 116: ReduceLROnPlateau reducing learning rate to 1.2000000424450263e-05.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9889 - loss: 0.0298 - val_accuracy: 0.9743 - val_loss: 0.1585 - val_f1_weighted: 0.9742 - learning_rate: 6.0000e-05
# Epoch 117/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9840 - loss: 0.0424 - val_f1_weighted: 0.9821
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9840 - loss: 0.0424 - val_accuracy: 0.9822 - val_loss: 0.1225 - val_f1_weighted: 0.9821 - learning_rate: 1.2000e-05
# Epoch 118/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9888 - loss: 0.0313 - val_f1_weighted: 0.9861
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9888 - loss: 0.0313 - val_accuracy: 0.9861 - val_loss: 0.1175 - val_f1_weighted: 0.9861 - learning_rate: 1.2000e-05
# Epoch 119/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9819 - loss: 0.0496 - val_f1_weighted: 0.9871
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9819 - loss: 0.0496 - val_accuracy: 0.9871 - val_loss: 0.1172 - val_f1_weighted: 0.9871 - learning_rate: 1.2000e-05
# Epoch 120/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9863 - loss: 0.0385 - val_f1_weighted: 0.9861
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9863 - loss: 0.0385 - val_accuracy: 0.9861 - val_loss: 0.1194 - val_f1_weighted: 0.9861 - learning_rate: 1.2000e-05
# Epoch 121/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9906 - loss: 0.0294 - val_f1_weighted: 0.9852
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9906 - loss: 0.0294 - val_accuracy: 0.9851 - val_loss: 0.1241 - val_f1_weighted: 0.9852 - learning_rate: 1.2000e-05
# Epoch 122/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9908 - loss: 0.0294 - val_f1_weighted: 0.9861
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9908 - loss: 0.0294 - val_accuracy: 0.9861 - val_loss: 0.1197 - val_f1_weighted: 0.9861 - learning_rate: 1.2000e-05
# Epoch 123/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9907 - loss: 0.0322 - val_f1_weighted: 0.9861
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9907 - loss: 0.0322 - val_accuracy: 0.9861 - val_loss: 0.1211 - val_f1_weighted: 0.9861 - learning_rate: 1.2000e-05
# Epoch 124/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9894 - loss: 0.0340 - val_f1_weighted: 0.9852
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9894 - loss: 0.0340 - val_accuracy: 0.9851 - val_loss: 0.1248 - val_f1_weighted: 0.9852 - learning_rate: 1.2000e-05
# Epoch 125/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9916 - loss: 0.0257 - val_f1_weighted: 0.9861
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9916 - loss: 0.0257 - val_accuracy: 0.9861 - val_loss: 0.1149 - val_f1_weighted: 0.9861 - learning_rate: 1.2000e-05
# Epoch 126/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9874 - loss: 0.0408 - val_f1_weighted: 0.9851
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9874 - loss: 0.0408 - val_accuracy: 0.9851 - val_loss: 0.1181 - val_f1_weighted: 0.9851 - learning_rate: 1.2000e-05
# Epoch 127/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9860 - loss: 0.0389 - val_f1_weighted: 0.9861
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9860 - loss: 0.0389 - val_accuracy: 0.9861 - val_loss: 0.1168 - val_f1_weighted: 0.9861 - learning_rate: 1.2000e-05
# Epoch 128/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9892 - loss: 0.0287 - val_f1_weighted: 0.9861
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9892 - loss: 0.0287 - val_accuracy: 0.9861 - val_loss: 0.1066 - val_f1_weighted: 0.9861 - learning_rate: 1.2000e-05
# Epoch 129/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9888 - loss: 0.0303 - val_f1_weighted: 0.9861
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9888 - loss: 0.0303 - val_accuracy: 0.9861 - val_loss: 0.1198 - val_f1_weighted: 0.9861 - learning_rate: 1.2000e-05
# Epoch 130/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9906 - loss: 0.0331 - val_f1_weighted: 0.9871
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9906 - loss: 0.0331 - val_accuracy: 0.9871 - val_loss: 0.1162 - val_f1_weighted: 0.9871 - learning_rate: 1.2000e-05
# Epoch 131/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9883 - loss: 0.0303 - val_f1_weighted: 0.9852
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9883 - loss: 0.0303 - val_accuracy: 0.9851 - val_loss: 0.1155 - val_f1_weighted: 0.9852 - learning_rate: 1.2000e-05
# Epoch 132/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9890 - loss: 0.0313 - val_f1_weighted: 0.9852
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9890 - loss: 0.0313 - val_accuracy: 0.9851 - val_loss: 0.1181 - val_f1_weighted: 0.9852 - learning_rate: 1.2000e-05
# Epoch 133/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9889 - loss: 0.0296 - val_f1_weighted: 0.9861
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9889 - loss: 0.0296 - val_accuracy: 0.9861 - val_loss: 0.1172 - val_f1_weighted: 0.9861 - learning_rate: 1.2000e-05
# Epoch 134/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9878 - loss: 0.0299 - val_f1_weighted: 0.9861
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.9878 - loss: 0.0299 - val_accuracy: 0.9861 - val_loss: 0.1168 - val_f1_weighted: 0.9861 - learning_rate: 1.2000e-05
# Epoch 135/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9877 - loss: 0.0304 - val_f1_weighted: 0.9871
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9877 - loss: 0.0304 - val_accuracy: 0.9871 - val_loss: 0.1147 - val_f1_weighted: 0.9871 - learning_rate: 1.2000e-05
# Epoch 136/200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9908 - loss: 0.0272 - val_f1_weighted: 0.9842
# Early stopping triggered based on weighted F1-score.
#
# Epoch 136: ReduceLROnPlateau reducing learning rate to 2.4000000848900527e-06.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9908 - loss: 0.0272 - val_accuracy: 0.9842 - val_loss: 0.1218 - val_f1_weighted: 0.9842 - learning_rate: 1.2000e-05
#
# --- Training Finished ---

# %% [markdown]
# ## **Evaluation**

# %%
# ===========================
# BLOCK 6: EVALUATION
# ===========================

print("\n\n--- Final Evaluation on BRISC2025 Test Set ---")
custom_objects = {
    'SpectralFilterLayer': SpectralFilterLayer,
    'BilinearFusion': BilinearFusion
}

try:
    print(f"Loading best model from: {CLASSIFIER_MODEL_PATH}")
    best_model = models.load_model(
        CLASSIFIER_MODEL_PATH,
        custom_objects = custom_objects}
    )

    # --- 1. Evaluating Loss and Accuracy ---
    print("\n--- Calculating Loss and Accuracy on Test Set ---")
    loss, accuracy = best_model.evaluate(X_test, y_test, verbose=0)
    print(f"Test Loss:      {loss:.4f}")
    print(f"Test Accuracy:  {accuracy:.4f}")

    # --- 2. Getting Predictions ---
    y_pred_proba = best_model.predict(X_test)
    y_pred_classes = np.argmax(y_pred_proba, axis=1)

    # --- 3. Detailed Metrics ---
    print("\n--- Detailed Performance Metrics ---")
    macro_f1 = f1_score(y_test, y_pred_classes, average='macro', zero_division=0)
    weighted_f1 = f1_score(y_test, y_pred_classes, average='weighted', zero_division=0)
    print(f"Macro F1 Score:   {macro_f1:.4f}")
    print(f"Weighted F1 Score:{weighted_f1:.4f}")

    kappa = cohen_kappa_score(y_test, y_pred_classes)
    mcc = matthews_corrcoef(y_test, y_pred_classes)
    print(f"Cohen's Kappa:    {kappa:.4f}")
    print(f"MCC:              {mcc:.4f}")

    auc_roc = roc_auc_score(y_test, y_pred_proba, multi_class='ovr', average='macro')
    weighted_auc_roc = roc_auc_score(y_test, y_pred_proba, multi_class='ovr', average='weighted')
    print(f"AUC-ROC (Macro):  {auc_roc:.4f}")
    print(f"AUC-ROC (Weighted):{weighted_auc_roc:.4f}")

    # --- 4. Classification Report ---
    print("\n--- Classification Report ---")
    print(classification_report(y_test, y_pred_classes, target_names=CLASS_NAMES, digits=4, zero_division=0))

    # --- 5. Confusion Matrix ---
    cm = confusion_matrix(y_test, y_pred_classes)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES)
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    # plt.title('Bilinear Fusion S³F-Net on BRISC2025')
    plt.show()

    # --- 6. Plotting Training History ---
    if 'history' in locals() or 'history' in globals():
        print("\n--- Training History Plots ---")
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6))
        ax1.plot(history.history['loss'], label='Train Loss')
        ax1.plot(history.history['val_loss'], label='Val Loss')
        ax1.set_title('Model Loss')
        ax1.set_xlabel('Epoch')
        ax1.legend()
        ax1.grid(True)
        ax2.plot(history.history['accuracy'], label='Train Accuracy')
        ax2.plot(history.history['val_accuracy'], label='Val Accuracy')
        if 'val_f1_weighted' in history.history:
            ax2.plot(history.history['val_f1_weighted'], label='Validation F1 (Weighted)', linestyle='--')
        ax2.set_title('Model Performance')
        ax2.set_xlabel('Epoch')
        ax2.legend()
        ax2.grid(True)
        plt.show()

    # --- 7. ROC Curve Plot ---
    print("\n--- ROC Curve Analysis ---")
    y_test_binarized = label_binarize(y_test, classes=range(len(CLASS_NAMES)))
    n_classes = y_test_binarized.shape[1]
    fpr, tpr, roc_auc_dict = dict(), dict(), dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test_binarized[:, i], y_pred_proba[:, i])
        roc_auc_dict[i] = auc(fpr[i], tpr[i])
    plt.figure(figsize=(10, 8))
    colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'red', 'green', 'purple', 'brown'])
    for i, color in zip(range(n_classes), colors):
        plt.plot(fpr[i], tpr[i], color=color, lw=2,
                 label=f'ROC curve of class {CLASS_NAMES[i]} (area = {roc_auc_dict[i]:.2f})')
    plt.plot([0, 1], [0, 1], 'k--', lw=2)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    # plt.title('Multi-Class Receiver Operating Characteristic (ROC)')
    plt.legend(loc="lower right")
    plt.grid(True)
    plt.show()

except Exception as e:
    print(f"An error occurred during evaluation: {e}")

print("\n--- Script Finished ---")
# Out:
# --- Final Evaluation on BRISC2025 Unseen Test Set ---
# Loading best model from: /content/drive/MyDrive/S2F_Net_Models/final_bilinear_s2f_net_BRISC.keras
#
# --- Calculating Loss and Accuracy on Test Set ---
# Test Loss:      0.1034
# Test Accuracy:  0.9881
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step
#
# --- Detailed Performance Metrics ---
# Macro F1 Score:   0.9884
# Weighted F1 Score:0.9881
# Cohen's Kappa:    0.9838
# MCC:              0.9838
# AUC-ROC (Macro):  0.9985
# AUC-ROC (Weighted):0.9982
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#       glioma     0.9960    0.9843    0.9901       254
#   meningioma     0.9804    0.9804    0.9804       306
#     no_tumor     0.9790    1.0000    0.9894       140
#    pituitary     0.9935    0.9935    0.9935       310
#
#     accuracy                         0.9881      1010
#    macro avg     0.9872    0.9895    0.9884      1010
# weighted avg     0.9882    0.9881    0.9881      1010
# --- Training History Plots ---
# --- ROC Curve Analysis ---
# --- Script Finished ---
