# %% [markdown]
# # **Spatial-Spectral Summarizer Fusion Network (S³F-Net) Spectral Baseline (SpectraNet) Implementation**

# %% [markdown]
# This notebook contains the full implementation of **SpectraNet** on the HAM10000 (Skin Lesion Segmentation/Classification) dataset (This is the final implementation after the model/hyperparameter tuning was finalized. The tuning process was also carried out primarily using the original HAM10000 dataset). We use the **SpectraNet-1** variant here, for comparisons with **S³F-Net** and the Baseline Spatial CNN. The full architecture is customizable, feel free to do so. Edit the file paths according to your setup.

# %% [markdown]
# ## **Data Preparation**

# %%
# ====================
# BLOCK 1: SETUP
# ====================

import os
import zipfile
from google.colab import drive

print("--- Mounting Google Drive ---")
drive.mount('/content/drive')

# --- Defining Paths ---
ZIP_PATH = "/content/drive/MyDrive/Medical Image Segmentation/HAM10000.zip"
TEMP_DATA_DIR = "/content/ham10000_temp"

# --- Unzip the Data ---
if not os.path.exists(TEMP_DATA_DIR):
    print(f"\n--- Unzipping dataset to local runtime for fast access... ---")
    os.makedirs(TEMP_DATA_DIR, exist_ok=True)
    try:
        with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
            zip_ref.extractall(TEMP_DATA_DIR)
        print("\n--- Unzipping complete! ---")
    except Exception as e:
        print(f"ERROR: Could not unzip file. Check ZIP_PATH. Error: {e}")
        exit()
else:
    print("\n--- Dataset already unzipped in this session. ---")
# Out:
# --- Mounting Google Drive ---
# Mounted at /content/drive
#
# --- Unzipping dataset to local runtime for fast access... ---
#
# --- Unzipping complete! ---

# %%
# ==============================================================================
# BLOCK 2: IMPORTS AND CONFIGURATION
# ==============================================================================
import cv2
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, callbacks
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score, cohen_kappa_score, matthews_corrcoef, roc_auc_score, roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle
import matplotlib.pyplot as plt
import seaborn as sns

# --- Configuration ---
IMG_SIZE = (225, 300)
BATCH_SIZE = 16
EPOCHS = 200
RANDOM_STATE = 42

# --- Paths ---
DATASET_BASE_PATH = "/content/ham10000_temp/HAM10000"
SAVE_FOLDER = "/content/drive/MyDrive/S3F_Net_Models"
os.makedirs(SAVE_FOLDER, exist_ok=True)
CLASSIFIER_MODEL_PATH = os.path.join(SAVE_FOLDER, "SpectraNet_1_HAM10000.keras")

# %%
# ==========================
# BLOCK 3: DATA LOADING
# ==========================
def load_ham10000_split(base_path, csv_filename, image_foldername):
    """Loads a specific split (train or test) of the HAM10000 dataset."""
    csv_path = os.path.join(base_path, csv_filename)
    image_dir = os.path.join(base_path, image_foldername)
    df = pd.read_csv(csv_path)
    class_names = list(df.columns[1:])
    labels_one_hot = df.iloc[:, 1:].values
    labels_int = np.argmax(labels_one_hot, axis=1)
    images = []
    image_ids = df['image'].values
    print(f"Loading {len(image_ids)} images from: {image_dir}")
    for img_id in image_ids:
        img_path = os.path.join(image_dir, f"{img_id}.jpg")
        try:
            img = cv2.imread(img_path); img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, (IMG_SIZE[1], IMG_SIZE[0]), interpolation=cv2.INTER_AREA)
            img = img.astype('float32') / 255.0
            images.append(img)
        except Exception: continue
    return np.array(images), np.array(labels_int), class_names

try:
    # --- Loading the two separate datasets ---
    X_train, y_train, CLASS_NAMES = load_ham10000_split(DATASET_BASE_PATH, 'GroundTruth.csv', 'images')
    X_test, y_test, _ = load_ham10000_split(DATASET_BASE_PATH, 'Test_GroundTruth.csv', 'Test_images')   # The Test set is basically the Test set provided for ISIC Challenge 2018.

    print("\n--- Data Loading Summary ---")
    print(f"Training set:   {len(X_train)} samples")
    print(f"Test set:       {len(X_test)} samples")
    print(f"Class names:    {CLASS_NAMES}")

    # Calculating class weights from the training set
    class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
    class_weights_dict = dict(enumerate(class_weights))
    print(f"Calculated class weights: {class_weights_dict}")
    print("\nData is ready for model training.")

except Exception as e:
    print(f"An error occurred during data loading: {e}"); exit()
# Out:
# Loading 10015 images from: /content/ham10000_temp/HAM10000/images
# Loading 1512 images from: /content/ham10000_temp/HAM10000/Test_images
#
# --- Data Loading Summary ---
# Training set:   10015 samples
# Test set:       1512 samples (will be used for validation and final testing)
# Class names:    ['MEL', 'NV', 'BCC', 'AKIEC', 'BKL', 'DF', 'VASC']
# Calculated class weights: {0: np.float64(1.2854575792581184), 1: np.float64(0.21338020666879728), 2: np.float64(2.78349082823791), 3: np.float64(4.375273044997815), 4: np.float64(1.301832835044846), 5: np.float64(12.440993788819876), 6: np.float64(10.075452716297788)}
#
# Data is ready for model training.

# %% [markdown]
# ## **SpectraNet-1 Model Building**

# %%
# ==============================================================================
# BLOCK 3: MODEL ARCHITECTURE (SpectraNet with 1 SpectralFilter Layer)
# ==============================================================================
# This block defines the SpectraNet-1 Architecture

# --- Custom SpectralFilter Layer & Encoders ---
class SpectralFilterLayer(layers.Layer):
    def __init__(self, filters, **kwargs): super().__init__(**kwargs); self.filters = filters
    def build(self, input_shape):
        _, h, w, c = input_shape
        fft_shape = (h, w // 2 + 1)
        self.real_weights = self.add_weight(name='real_weights', shape=(c, self.filters, *fft_shape), initializer='glorot_uniform')
        self.imag_weights = self.add_weight(name='imag_weights', shape=(c, self.filters, *fft_shape), initializer='glorot_uniform')
        self.bias = self.add_weight(name='bias', shape=(self.filters,), initializer='zeros')
    def call(self, inputs):
        inputs_p = tf.transpose(inputs, [0, 3, 1, 2])
        inputs_fft = tf.signal.rfft2d(inputs_p)
        kernel_fft = tf.complex(self.real_weights, self.imag_weights)
        output_fft = tf.einsum('bchw,cfhw->bfhw', inputs_fft, kernel_fft)
        output_s = tf.signal.irfft2d(output_fft)
        output_p = tf.transpose(output_s, [0, 2, 3, 1])
        return output_p + self.bias
    def get_config(self):
        config = super().get_config()
        config.update({"filters": self.filters})
        return config

def depthwise_sep_block(x, filters, kernel_size=3, strides=1):
    x = layers.DepthwiseConv2D(kernel_size, strides=strides, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = layers.Conv2D(filters, 1, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    return x

def build_spectral_summary_branch(inputs):
    x = SpectralFilterLayer(32)(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = depthwise_sep_block(x, 64)
    x = layers.MaxPooling2D(2)(x)

    x = depthwise_sep_block(x, 128)
    x = layers.MaxPooling2D(2)(x)

    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(16, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.1875)(x)
    x = layers.Dense(4, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.3125)(x)

    return x

# --- SpectraNet Model Builder ---
def build_spectral_only_classifier(input_shape, num_classes):
    """Builds the SpectraNet-1 model for classification."""
    inputs = layers.Input(input_shape)

    # 1. Building the spectral summary branch
    spectral_vector = build_spectral_summary_branch(inputs)

    # 2. Output Layer
    outputs = layers.Dense(num_classes, activation='softmax')(spectral_vector)

    model = models.Model(inputs, outputs, name="SpectraNet_1_Classifier")

    # Compiling with the same optimizer and CE loss as S³F-Net
    model.compile(optimizer=optimizers.Adam(0.0003),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

print("SpectraNet model architecture is ready.")
# Out:
# SpectraNet model architecture is ready.

# %% [markdown]
# ## **Model Training**

# %%
# ==============================================================================
# BLOCK 4: CUSTOM CALLBACK AND TRAINING
# ==============================================================================
from sklearn.metrics import f1_score

# --- Custom F1 Score Callback to use 'weighted' average ---
class F1ScoreCallback(callbacks.Callback):
    def __init__(self, validation_data, filepath, patience=25):
        super(F1ScoreCallback, self).__init__()
        self.validation_data = validation_data
        self.filepath = filepath
        self.patience = patience
        self.best_f1 = -1.0
        self.wait = 0

    def on_epoch_end(self, epoch, logs=None):
        X_val, y_val = self.validation_data
        y_pred_proba = self.model.predict(X_val, verbose=0)
        y_pred = np.argmax(y_pred_proba, axis=1)

        weighted_f1 = f1_score(y_val, y_pred, average='weighted')
        logs['val_f1_weighted'] = weighted_f1

        print(f" - val_f1_weighted: {weighted_f1:.4f}", end="")

        if weighted_f1 > self.best_f1:
            print(f" (New best F1, saving model to {self.filepath})")
            self.best_f1 = weighted_f1
            self.model.save(self.filepath)
            self.wait = 0
        else:
            print()
            self.wait += 1
            if self.wait >= self.patience:
                print("Early stopping triggered based on weighted F1-score.")
                self.model.stop_training = True

# --- Defining the model path ---
CLASSIFIER_MODEL_PATH = os.path.join(SAVE_FOLDER, "SpectraNet_1_HAM10000.keras")

# --- Building the Model ---
print("\n--- Building SpectraNet ---")
classifier_model = build_spectral_only_classifier(X_train.shape[1:], num_classes=len(CLASS_NAMES))

# --- Compiling the model with standard cross-entropy ---
classifier_model.compile(optimizer=optimizers.Adam(0.0003),
                         loss='sparse_categorical_crossentropy',
                         metrics=['accuracy'])
classifier_model.summary()

# --- Defining Callbacks ---
f1_callback = F1ScoreCallback(validation_data=(X_test, y_test),
                              filepath=CLASSIFIER_MODEL_PATH,
                              patience=40)

reduce_lr = callbacks.ReduceLROnPlateau(monitor='val_loss',
                                        factor=0.2,
                                        patience=20,
                                        min_lr=1e-6,
                                        verbose=1)

# --- Training the Model ---
print("\n--- Training (Monitoring Weighted F1-Score) ---")
history = classifier_model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    class_weight=class_weights_dict,
    callbacks=[f1_callback, reduce_lr]
)

print("\n--- Training Finished ---")
# Out:
# --- Building Spectral-Net ---
# Model: "Spectral_Only_Classifier"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 225, 300, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spectral_conv_layer_2           │ (None, 225, 300, 32)   │     6,523,232 │
# │ (SpectralConvLayer)             │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 225, 300, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_4 (ReLU)                  │ (None, 225, 300, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ depthwise_conv2d_1              │ (None, 225, 300, 32)   │           288 │
# │ (DepthwiseConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 225, 300, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_5 (ReLU)                  │ (None, 225, 300, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 225, 300, 64)   │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 225, 300, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_6 (ReLU)                  │ (None, 225, 300, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 112, 150, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ depthwise_conv2d_2              │ (None, 112, 150, 64)   │           576 │
# │ (DepthwiseConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 112, 150, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_7 (ReLU)                  │ (None, 112, 150, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 112, 150, 128)  │         8,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 112, 150, 128)  │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_8 (ReLU)                  │ (None, 112, 150, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 56, 75, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 16)             │         2,064 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 16)             │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 4)              │            68 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 4)              │            16 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 4)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 7)              │            35 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,537,863 (24.94 MB)
#  Trainable params: 6,537,183 (24.94 MB)
#  Non-trainable params: 680 (2.66 KB)
# --- Training (Monitoring Weighted F1-Score) ---
# Epoch 1/200
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.1245 - loss: 2.2235 - val_f1_weighted: 0.1482 (New best F1, saving model to /content/drive/MyDrive/S2F_Net_Models/SpectralNet_1SC_HAM10000.keras)
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 63s 73ms/step - accuracy: 0.1245 - loss: 2.2233 - val_accuracy: 0.1085 - val_loss: 1.8242 - val_f1_weighted: 0.1482 - learning_rate: 3.0000e-04
# Epoch 2/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.1732 - loss: 1.9434 - val_f1_weighted: 0.2650 (New best F1, saving model to /content/drive/MyDrive/S2F_Net_Models/SpectralNet_1SC_HAM10000.keras)
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - accuracy: 0.1732 - loss: 1.9433 - val_accuracy: 0.2388 - val_loss: 1.9181 - val_f1_weighted: 0.2650 - learning_rate: 3.0000e-04
# Epoch 3/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.2418 - loss: 1.8417 - val_f1_weighted: 0.3629 (New best F1, saving model to /content/drive/MyDrive/S2F_Net_Models/SpectralNet_1SC_HAM10000.keras)
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - accuracy: 0.2418 - loss: 1.8417 - val_accuracy: 0.3247 - val_loss: 1.6719 - val_f1_weighted: 0.3629 - learning_rate: 3.0000e-04
# Epoch 4/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3007 - loss: 1.8044 - val_f1_weighted: 0.3357
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.3007 - loss: 1.8044 - val_accuracy: 0.2672 - val_loss: 1.8070 - val_f1_weighted: 0.3357 - learning_rate: 3.0000e-04
# Epoch 5/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3421 - loss: 1.7769 - val_f1_weighted: 0.0685
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.3421 - loss: 1.7769 - val_accuracy: 0.1369 - val_loss: 2.7050 - val_f1_weighted: 0.0685 - learning_rate: 3.0000e-04
# Epoch 6/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3633 - loss: 1.6845 - val_f1_weighted: 0.4809 (New best F1, saving model to /content/drive/MyDrive/S2F_Net_Models/SpectralNet_1SC_HAM10000.keras)
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - accuracy: 0.3633 - loss: 1.6846 - val_accuracy: 0.4716 - val_loss: 1.5460 - val_f1_weighted: 0.4809 - learning_rate: 3.0000e-04
# Epoch 7/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3545 - loss: 1.6305 - val_f1_weighted: 0.0858
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.3545 - loss: 1.6306 - val_accuracy: 0.1329 - val_loss: 2.1710 - val_f1_weighted: 0.0858 - learning_rate: 3.0000e-04
# Epoch 8/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3467 - loss: 1.6694 - val_f1_weighted: 0.4469
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.3467 - loss: 1.6693 - val_accuracy: 0.3955 - val_loss: 1.5633 - val_f1_weighted: 0.4469 - learning_rate: 3.0000e-04
# Epoch 9/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3704 - loss: 1.5269 - val_f1_weighted: 0.4812 (New best F1, saving model to /content/drive/MyDrive/S2F_Net_Models/SpectralNet_1SC_HAM10000.keras)
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - accuracy: 0.3704 - loss: 1.5271 - val_accuracy: 0.4491 - val_loss: 1.3709 - val_f1_weighted: 0.4812 - learning_rate: 3.0000e-04
# Epoch 10/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3749 - loss: 1.5136 - val_f1_weighted: 0.4537
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.3749 - loss: 1.5137 - val_accuracy: 0.5040 - val_loss: 1.4058 - val_f1_weighted: 0.4537 - learning_rate: 3.0000e-04
# Epoch 11/200
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3782 - loss: 1.4957 - val_f1_weighted: 0.4465
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.3782 - loss: 1.4957 - val_accuracy: 0.4120 - val_loss: 1.4495 - val_f1_weighted: 0.4465 - learning_rate: 3.0000e-04
# Epoch 12/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4019 - loss: 1.4912 - val_f1_weighted: 0.2898
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.4019 - loss: 1.4911 - val_accuracy: 0.2824 - val_loss: 1.8807 - val_f1_weighted: 0.2898 - learning_rate: 3.0000e-04
# Epoch 13/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3914 - loss: 1.4075 - val_f1_weighted: 0.3239
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.3914 - loss: 1.4076 - val_accuracy: 0.3062 - val_loss: 1.8600 - val_f1_weighted: 0.3239 - learning_rate: 3.0000e-04
# Epoch 14/200
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4190 - loss: 1.4217 - val_f1_weighted: 0.4431
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.4190 - loss: 1.4216 - val_accuracy: 0.3942 - val_loss: 1.5580 - val_f1_weighted: 0.4431 - learning_rate: 3.0000e-04
# Epoch 15/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4225 - loss: 1.3651 - val_f1_weighted: 0.0932
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.4225 - loss: 1.3651 - val_accuracy: 0.1124 - val_loss: 1.9395 - val_f1_weighted: 0.0932 - learning_rate: 3.0000e-04
# Epoch 16/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4326 - loss: 1.3225 - val_f1_weighted: 0.3876
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.4326 - loss: 1.3227 - val_accuracy: 0.3393 - val_loss: 1.4953 - val_f1_weighted: 0.3876 - learning_rate: 3.0000e-04
# Epoch 17/200
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4556 - loss: 1.2737 - val_f1_weighted: 0.3497
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.4556 - loss: 1.2738 - val_accuracy: 0.2996 - val_loss: 1.8309 - val_f1_weighted: 0.3497 - learning_rate: 3.0000e-04
# Epoch 18/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4547 - loss: 1.2211 - val_f1_weighted: 0.4796
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.4547 - loss: 1.2213 - val_accuracy: 0.5992 - val_loss: 1.6506 - val_f1_weighted: 0.4796 - learning_rate: 3.0000e-04
# Epoch 19/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4494 - loss: 1.2391 - val_f1_weighted: 0.3539
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.4493 - loss: 1.2390 - val_accuracy: 0.3228 - val_loss: 1.5727 - val_f1_weighted: 0.3539 - learning_rate: 3.0000e-04
# Epoch 20/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4551 - loss: 1.1839 - val_f1_weighted: 0.2756
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.4551 - loss: 1.1839 - val_accuracy: 0.2149 - val_loss: 1.9764 - val_f1_weighted: 0.2756 - learning_rate: 3.0000e-04
# Epoch 21/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4637 - loss: 1.1362 - val_f1_weighted: 0.2717
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.4638 - loss: 1.1361 - val_accuracy: 0.2315 - val_loss: 1.8314 - val_f1_weighted: 0.2717 - learning_rate: 3.0000e-04
# Epoch 22/200
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4773 - loss: 1.1587 - val_f1_weighted: 0.1868
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.4773 - loss: 1.1587 - val_accuracy: 0.1852 - val_loss: 2.2392 - val_f1_weighted: 0.1868 - learning_rate: 3.0000e-04
# Epoch 23/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4800 - loss: 1.0916 - val_f1_weighted: 0.4664
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.4800 - loss: 1.0916 - val_accuracy: 0.4272 - val_loss: 1.5103 - val_f1_weighted: 0.4664 - learning_rate: 3.0000e-04
# Epoch 24/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4691 - loss: 1.1137 - val_f1_weighted: 0.1921
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.4691 - loss: 1.1136 - val_accuracy: 0.2249 - val_loss: 2.1591 - val_f1_weighted: 0.1921 - learning_rate: 3.0000e-04
# Epoch 25/200
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4860 - loss: 1.0162 - val_f1_weighted: 0.2737
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.4860 - loss: 1.0163 - val_accuracy: 0.2454 - val_loss: 1.7916 - val_f1_weighted: 0.2737 - learning_rate: 3.0000e-04
# Epoch 26/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5027 - loss: 0.9980 - val_f1_weighted: 0.2589
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.5027 - loss: 0.9980 - val_accuracy: 0.2116 - val_loss: 2.4025 - val_f1_weighted: 0.2589 - learning_rate: 3.0000e-04
# Epoch 27/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4839 - loss: 1.0294 - val_f1_weighted: 0.4752
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.4839 - loss: 1.0292 - val_accuracy: 0.4497 - val_loss: 1.2752 - val_f1_weighted: 0.4752 - learning_rate: 3.0000e-04
# Epoch 28/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4968 - loss: 1.0193 - val_f1_weighted: 0.3497
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.4968 - loss: 1.0192 - val_accuracy: 0.3267 - val_loss: 1.5936 - val_f1_weighted: 0.3497 - learning_rate: 3.0000e-04
# Epoch 29/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5226 - loss: 0.9500 - val_f1_weighted: 0.4791
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.5225 - loss: 0.9501 - val_accuracy: 0.4702 - val_loss: 1.3493 - val_f1_weighted: 0.4791 - learning_rate: 3.0000e-04
# Epoch 30/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5178 - loss: 0.9095 - val_f1_weighted: 0.4904 (New best F1, saving model to /content/drive/MyDrive/S2F_Net_Models/SpectralNet_1SC_HAM10000.keras)
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - accuracy: 0.5178 - loss: 0.9097 - val_accuracy: 0.4385 - val_loss: 1.3521 - val_f1_weighted: 0.4904 - learning_rate: 3.0000e-04
# Epoch 31/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5096 - loss: 0.8924 - val_f1_weighted: 0.4447
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.5096 - loss: 0.8924 - val_accuracy: 0.3849 - val_loss: 1.8018 - val_f1_weighted: 0.4447 - learning_rate: 3.0000e-04
# Epoch 32/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5290 - loss: 0.9235 - val_f1_weighted: 0.4081
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.5290 - loss: 0.9235 - val_accuracy: 0.3664 - val_loss: 1.5304 - val_f1_weighted: 0.4081 - learning_rate: 3.0000e-04
# Epoch 33/200
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5487 - loss: 0.8480 - val_f1_weighted: 0.0024
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.5487 - loss: 0.8480 - val_accuracy: 0.0238 - val_loss: 5.2231 - val_f1_weighted: 0.0024 - learning_rate: 3.0000e-04
# Epoch 34/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5358 - loss: 0.8967 - val_f1_weighted: 0.4844
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.5358 - loss: 0.8967 - val_accuracy: 0.5225 - val_loss: 1.5921 - val_f1_weighted: 0.4844 - learning_rate: 3.0000e-04
# Epoch 35/200
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5442 - loss: 0.8546 - val_f1_weighted: 0.2917
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.5442 - loss: 0.8546 - val_accuracy: 0.2890 - val_loss: 1.9596 - val_f1_weighted: 0.2917 - learning_rate: 3.0000e-04
# Epoch 36/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5729 - loss: 0.7523 - val_f1_weighted: 0.5222 (New best F1, saving model to /content/drive/MyDrive/S2F_Net_Models/SpectralNet_1SC_HAM10000.keras)
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - accuracy: 0.5729 - loss: 0.7525 - val_accuracy: 0.5317 - val_loss: 1.3869 - val_f1_weighted: 0.5222 - learning_rate: 3.0000e-04
# Epoch 37/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5721 - loss: 0.7733 - val_f1_weighted: 0.2465
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.5721 - loss: 0.7733 - val_accuracy: 0.2083 - val_loss: 2.7486 - val_f1_weighted: 0.2465 - learning_rate: 3.0000e-04
# Epoch 38/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5403 - loss: 0.9336 - val_f1_weighted: 0.0744
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.5403 - loss: 0.9332 - val_accuracy: 0.1349 - val_loss: 4.7435 - val_f1_weighted: 0.0744 - learning_rate: 3.0000e-04
# Epoch 39/200
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5521 - loss: 0.7900 - val_f1_weighted: 0.5064
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.5521 - loss: 0.7900 - val_accuracy: 0.4729 - val_loss: 1.5021 - val_f1_weighted: 0.5064 - learning_rate: 3.0000e-04
# Epoch 40/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5760 - loss: 0.7487 - val_f1_weighted: 0.3455
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.5761 - loss: 0.7487 - val_accuracy: 0.3122 - val_loss: 1.8972 - val_f1_weighted: 0.3455 - learning_rate: 3.0000e-04
# Epoch 41/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5895 - loss: 0.7307 - val_f1_weighted: 0.1487
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.5894 - loss: 0.7308 - val_accuracy: 0.1362 - val_loss: 2.6776 - val_f1_weighted: 0.1487 - learning_rate: 3.0000e-04
# Epoch 42/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5993 - loss: 0.7281 - val_f1_weighted: 0.1258
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.5993 - loss: 0.7281 - val_accuracy: 0.1111 - val_loss: 2.7803 - val_f1_weighted: 0.1258 - learning_rate: 3.0000e-04
# Epoch 43/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6233 - loss: 0.7150 - val_f1_weighted: 0.4808
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.6233 - loss: 0.7149 - val_accuracy: 0.4292 - val_loss: 1.6282 - val_f1_weighted: 0.4808 - learning_rate: 3.0000e-04
# Epoch 44/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6201 - loss: 0.7081 - val_f1_weighted: 0.4725
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.6200 - loss: 0.7083 - val_accuracy: 0.6032 - val_loss: 1.6373 - val_f1_weighted: 0.4725 - learning_rate: 3.0000e-04
# Epoch 45/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5799 - loss: 0.8487 - val_f1_weighted: 0.2638
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.5799 - loss: 0.8485 - val_accuracy: 0.2672 - val_loss: 2.0268 - val_f1_weighted: 0.2638 - learning_rate: 3.0000e-04
# Epoch 46/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6082 - loss: 0.7695 - val_f1_weighted: 0.3629
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.6082 - loss: 0.7694 - val_accuracy: 0.3307 - val_loss: 1.4692 - val_f1_weighted: 0.3629 - learning_rate: 3.0000e-04
# Epoch 47/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5987 - loss: 0.7302 - val_f1_weighted: 0.5111
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 6.000000284984708e-05.
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.5987 - loss: 0.7302 - val_accuracy: 0.4795 - val_loss: 1.7874 - val_f1_weighted: 0.5111 - learning_rate: 3.0000e-04
# Epoch 48/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6467 - loss: 0.6878 - val_f1_weighted: 0.6114 (New best F1, saving model to /content/drive/MyDrive/S2F_Net_Models/SpectralNet_1SC_HAM10000.keras)
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - accuracy: 0.6467 - loss: 0.6877 - val_accuracy: 0.5899 - val_loss: 1.1884 - val_f1_weighted: 0.6114 - learning_rate: 6.0000e-05
# Epoch 49/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6639 - loss: 0.6071 - val_f1_weighted: 0.6152 (New best F1, saving model to /content/drive/MyDrive/S2F_Net_Models/SpectralNet_1SC_HAM10000.keras)
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - accuracy: 0.6639 - loss: 0.6071 - val_accuracy: 0.6104 - val_loss: 1.1054 - val_f1_weighted: 0.6152 - learning_rate: 6.0000e-05
# Epoch 50/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6657 - loss: 0.5935 - val_f1_weighted: 0.5556
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.6658 - loss: 0.5935 - val_accuracy: 0.5139 - val_loss: 1.2966 - val_f1_weighted: 0.5556 - learning_rate: 6.0000e-05
# Epoch 51/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6920 - loss: 0.6229 - val_f1_weighted: 0.5448
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.6920 - loss: 0.6229 - val_accuracy: 0.5007 - val_loss: 1.2803 - val_f1_weighted: 0.5448 - learning_rate: 6.0000e-05
# Epoch 52/200
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6814 - loss: 0.5770 - val_f1_weighted: 0.5952
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.6814 - loss: 0.5771 - val_accuracy: 0.5668 - val_loss: 1.2025 - val_f1_weighted: 0.5952 - learning_rate: 6.0000e-05
# Epoch 53/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6889 - loss: 0.5895 - val_f1_weighted: 0.5201
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.6889 - loss: 0.5896 - val_accuracy: 0.4815 - val_loss: 1.3509 - val_f1_weighted: 0.5201 - learning_rate: 6.0000e-05
# Epoch 54/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6816 - loss: 0.6414 - val_f1_weighted: 0.5817
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.6816 - loss: 0.6413 - val_accuracy: 0.6111 - val_loss: 1.1608 - val_f1_weighted: 0.5817 - learning_rate: 6.0000e-05
# Epoch 55/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6737 - loss: 0.6128 - val_f1_weighted: 0.5520
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.6737 - loss: 0.6129 - val_accuracy: 0.5152 - val_loss: 1.2970 - val_f1_weighted: 0.5520 - learning_rate: 6.0000e-05
# Epoch 56/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6959 - loss: 0.5638 - val_f1_weighted: 0.5919
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.6959 - loss: 0.5639 - val_accuracy: 0.5575 - val_loss: 1.2773 - val_f1_weighted: 0.5919 - learning_rate: 6.0000e-05
# Epoch 57/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7149 - loss: 0.5568 - val_f1_weighted: 0.4362
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7149 - loss: 0.5569 - val_accuracy: 0.4008 - val_loss: 1.5891 - val_f1_weighted: 0.4362 - learning_rate: 6.0000e-05
# Epoch 58/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7084 - loss: 0.5771 - val_f1_weighted: 0.5893
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7084 - loss: 0.5771 - val_accuracy: 0.5595 - val_loss: 1.2028 - val_f1_weighted: 0.5893 - learning_rate: 6.0000e-05
# Epoch 59/200
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7080 - loss: 0.6005 - val_f1_weighted: 0.6333 (New best F1, saving model to /content/drive/MyDrive/S2F_Net_Models/SpectralNet_1SC_HAM10000.keras)
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 18s 28ms/step - accuracy: 0.7080 - loss: 0.6005 - val_accuracy: 0.6323 - val_loss: 1.0745 - val_f1_weighted: 0.6333 - learning_rate: 6.0000e-05
# Epoch 60/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7072 - loss: 0.5627 - val_f1_weighted: 0.5154
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7073 - loss: 0.5627 - val_accuracy: 0.4722 - val_loss: 1.5383 - val_f1_weighted: 0.5154 - learning_rate: 6.0000e-05
# Epoch 61/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7189 - loss: 0.5748 - val_f1_weighted: 0.3869
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7189 - loss: 0.5747 - val_accuracy: 0.3598 - val_loss: 1.7355 - val_f1_weighted: 0.3869 - learning_rate: 6.0000e-05
# Epoch 62/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7086 - loss: 0.5613 - val_f1_weighted: 0.5406
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - accuracy: 0.7086 - loss: 0.5614 - val_accuracy: 0.5384 - val_loss: 1.3222 - val_f1_weighted: 0.5406 - learning_rate: 6.0000e-05
# Epoch 63/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7276 - loss: 0.5671 - val_f1_weighted: 0.5862
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7276 - loss: 0.5671 - val_accuracy: 0.5754 - val_loss: 1.1709 - val_f1_weighted: 0.5862 - learning_rate: 6.0000e-05
# Epoch 64/200
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7397 - loss: 0.5411 - val_f1_weighted: 0.6097
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7397 - loss: 0.5412 - val_accuracy: 0.5899 - val_loss: 1.1866 - val_f1_weighted: 0.6097 - learning_rate: 6.0000e-05
# Epoch 65/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7369 - loss: 0.5605 - val_f1_weighted: 0.5978
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7369 - loss: 0.5604 - val_accuracy: 0.5807 - val_loss: 1.2044 - val_f1_weighted: 0.5978 - learning_rate: 6.0000e-05
# Epoch 66/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7346 - loss: 0.5605 - val_f1_weighted: 0.5903
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7346 - loss: 0.5605 - val_accuracy: 0.5608 - val_loss: 1.3278 - val_f1_weighted: 0.5903 - learning_rate: 6.0000e-05
# Epoch 67/200
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7416 - loss: 0.5443 - val_f1_weighted: 0.6048
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7416 - loss: 0.5443 - val_accuracy: 0.5939 - val_loss: 1.1555 - val_f1_weighted: 0.6048 - learning_rate: 6.0000e-05
# Epoch 68/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7465 - loss: 0.5319 - val_f1_weighted: 0.5658
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7465 - loss: 0.5319 - val_accuracy: 0.5390 - val_loss: 1.4421 - val_f1_weighted: 0.5658 - learning_rate: 6.0000e-05
# Epoch 69/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7440 - loss: 0.5437 - val_f1_weighted: 0.5948
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7440 - loss: 0.5437 - val_accuracy: 0.5714 - val_loss: 1.1841 - val_f1_weighted: 0.5948 - learning_rate: 6.0000e-05
# Epoch 70/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7440 - loss: 0.5047 - val_f1_weighted: 0.5431
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7440 - loss: 0.5048 - val_accuracy: 0.4947 - val_loss: 1.4758 - val_f1_weighted: 0.5431 - learning_rate: 6.0000e-05
# Epoch 71/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7469 - loss: 0.5829 - val_f1_weighted: 0.5794
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7470 - loss: 0.5827 - val_accuracy: 0.6104 - val_loss: 1.2176 - val_f1_weighted: 0.5794 - learning_rate: 6.0000e-05
# Epoch 72/200
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7439 - loss: 0.5535 - val_f1_weighted: 0.6206
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7439 - loss: 0.5534 - val_accuracy: 0.6032 - val_loss: 1.1525 - val_f1_weighted: 0.6206 - learning_rate: 6.0000e-05
# Epoch 73/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7588 - loss: 0.5485 - val_f1_weighted: 0.5952
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7587 - loss: 0.5485 - val_accuracy: 0.5840 - val_loss: 1.1971 - val_f1_weighted: 0.5952 - learning_rate: 6.0000e-05
# Epoch 74/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7611 - loss: 0.5318 - val_f1_weighted: 0.6058
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7610 - loss: 0.5317 - val_accuracy: 0.6058 - val_loss: 1.1850 - val_f1_weighted: 0.6058 - learning_rate: 6.0000e-05
# Epoch 75/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7554 - loss: 0.5460 - val_f1_weighted: 0.6044
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7554 - loss: 0.5459 - val_accuracy: 0.6224 - val_loss: 1.1449 - val_f1_weighted: 0.6044 - learning_rate: 6.0000e-05
# Epoch 76/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7709 - loss: 0.5067 - val_f1_weighted: 0.5966
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7709 - loss: 0.5068 - val_accuracy: 0.6144 - val_loss: 1.1524 - val_f1_weighted: 0.5966 - learning_rate: 6.0000e-05
# Epoch 77/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7765 - loss: 0.5311 - val_f1_weighted: 0.5515
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7764 - loss: 0.5311 - val_accuracy: 0.5119 - val_loss: 1.4944 - val_f1_weighted: 0.5515 - learning_rate: 6.0000e-05
# Epoch 78/200
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7636 - loss: 0.5235 - val_f1_weighted: 0.5653
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7636 - loss: 0.5235 - val_accuracy: 0.5582 - val_loss: 1.3945 - val_f1_weighted: 0.5653 - learning_rate: 6.0000e-05
# Epoch 79/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7744 - loss: 0.5341 - val_f1_weighted: 0.6017
#
# Epoch 79: ReduceLROnPlateau reducing learning rate to 1.2000000424450263e-05.
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7745 - loss: 0.5340 - val_accuracy: 0.6376 - val_loss: 1.1488 - val_f1_weighted: 0.6017 - learning_rate: 6.0000e-05
# Epoch 80/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7826 - loss: 0.5183 - val_f1_weighted: 0.6289
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7826 - loss: 0.5182 - val_accuracy: 0.6078 - val_loss: 1.1595 - val_f1_weighted: 0.6289 - learning_rate: 1.2000e-05
# Epoch 81/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7872 - loss: 0.5146 - val_f1_weighted: 0.6408 (New best F1, saving model to /content/drive/MyDrive/S2F_Net_Models/SpectralNet_1SC_HAM10000.keras)
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 18s 28ms/step - accuracy: 0.7872 - loss: 0.5145 - val_accuracy: 0.6310 - val_loss: 1.1092 - val_f1_weighted: 0.6408 - learning_rate: 1.2000e-05
# Epoch 82/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7885 - loss: 0.5237 - val_f1_weighted: 0.6184
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7885 - loss: 0.5237 - val_accuracy: 0.5972 - val_loss: 1.1851 - val_f1_weighted: 0.6184 - learning_rate: 1.2000e-05
# Epoch 83/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7839 - loss: 0.5015 - val_f1_weighted: 0.6226
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7839 - loss: 0.5015 - val_accuracy: 0.6019 - val_loss: 1.1521 - val_f1_weighted: 0.6226 - learning_rate: 1.2000e-05
# Epoch 84/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7947 - loss: 0.5111 - val_f1_weighted: 0.6269
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7947 - loss: 0.5111 - val_accuracy: 0.6058 - val_loss: 1.1774 - val_f1_weighted: 0.6269 - learning_rate: 1.2000e-05
# Epoch 85/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7973 - loss: 0.5034 - val_f1_weighted: 0.6214
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7973 - loss: 0.5034 - val_accuracy: 0.6005 - val_loss: 1.1684 - val_f1_weighted: 0.6214 - learning_rate: 1.2000e-05
# Epoch 86/200
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7972 - loss: 0.5005 - val_f1_weighted: 0.6006
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7972 - loss: 0.5005 - val_accuracy: 0.5761 - val_loss: 1.2066 - val_f1_weighted: 0.6006 - learning_rate: 1.2000e-05
# Epoch 87/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7868 - loss: 0.5075 - val_f1_weighted: 0.6260
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7868 - loss: 0.5075 - val_accuracy: 0.6052 - val_loss: 1.1554 - val_f1_weighted: 0.6260 - learning_rate: 1.2000e-05
# Epoch 88/200
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7992 - loss: 0.4843 - val_f1_weighted: 0.6202
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7991 - loss: 0.4844 - val_accuracy: 0.6052 - val_loss: 1.1605 - val_f1_weighted: 0.6202 - learning_rate: 1.2000e-05
# Epoch 89/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7955 - loss: 0.5067 - val_f1_weighted: 0.6241
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7955 - loss: 0.5066 - val_accuracy: 0.6045 - val_loss: 1.1765 - val_f1_weighted: 0.6241 - learning_rate: 1.2000e-05
# Epoch 90/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7919 - loss: 0.5122 - val_f1_weighted: 0.6154
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7919 - loss: 0.5122 - val_accuracy: 0.5906 - val_loss: 1.1912 - val_f1_weighted: 0.6154 - learning_rate: 1.2000e-05
# Epoch 91/200
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8116 - loss: 0.5078 - val_f1_weighted: 0.6235
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.8116 - loss: 0.5077 - val_accuracy: 0.6038 - val_loss: 1.1903 - val_f1_weighted: 0.6235 - learning_rate: 1.2000e-05
# Epoch 92/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7948 - loss: 0.4631 - val_f1_weighted: 0.6338
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7948 - loss: 0.4632 - val_accuracy: 0.6197 - val_loss: 1.1370 - val_f1_weighted: 0.6338 - learning_rate: 1.2000e-05
# Epoch 93/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7972 - loss: 0.5009 - val_f1_weighted: 0.6278
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7971 - loss: 0.5009 - val_accuracy: 0.6138 - val_loss: 1.1509 - val_f1_weighted: 0.6278 - learning_rate: 1.2000e-05
# Epoch 94/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8048 - loss: 0.4591 - val_f1_weighted: 0.6316
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.8047 - loss: 0.4592 - val_accuracy: 0.6177 - val_loss: 1.1451 - val_f1_weighted: 0.6316 - learning_rate: 1.2000e-05
# Epoch 95/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7944 - loss: 0.4801 - val_f1_weighted: 0.6000
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7945 - loss: 0.4802 - val_accuracy: 0.5708 - val_loss: 1.2445 - val_f1_weighted: 0.6000 - learning_rate: 1.2000e-05
# Epoch 96/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8006 - loss: 0.5128 - val_f1_weighted: 0.6074
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.8006 - loss: 0.5128 - val_accuracy: 0.5813 - val_loss: 1.1978 - val_f1_weighted: 0.6074 - learning_rate: 1.2000e-05
# Epoch 97/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8010 - loss: 0.4933 - val_f1_weighted: 0.6254
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.8010 - loss: 0.4932 - val_accuracy: 0.6091 - val_loss: 1.1630 - val_f1_weighted: 0.6254 - learning_rate: 1.2000e-05
# Epoch 98/200
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8140 - loss: 0.4760 - val_f1_weighted: 0.6057
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.8140 - loss: 0.4760 - val_accuracy: 0.5754 - val_loss: 1.2276 - val_f1_weighted: 0.6057 - learning_rate: 1.2000e-05
# Epoch 99/200
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8069 - loss: 0.4479 - val_f1_weighted: 0.5974
#
# Epoch 99: ReduceLROnPlateau reducing learning rate to 2.4000000848900527e-06.
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.8069 - loss: 0.4479 - val_accuracy: 0.5774 - val_loss: 1.2038 - val_f1_weighted: 0.5974 - learning_rate: 1.2000e-05
# Epoch 100/200
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8064 - loss: 0.4698 - val_f1_weighted: 0.6325
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.8064 - loss: 0.4699 - val_accuracy: 0.6164 - val_loss: 1.1502 - val_f1_weighted: 0.6325 - learning_rate: 2.4000e-06
# Epoch 101/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7932 - loss: 0.5295 - val_f1_weighted: 0.6309
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7932 - loss: 0.5294 - val_accuracy: 0.6171 - val_loss: 1.1408 - val_f1_weighted: 0.6309 - learning_rate: 2.4000e-06
# Epoch 102/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8131 - loss: 0.4991 - val_f1_weighted: 0.6289
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.8131 - loss: 0.4990 - val_accuracy: 0.6104 - val_loss: 1.1715 - val_f1_weighted: 0.6289 - learning_rate: 2.4000e-06
# Epoch 103/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8025 - loss: 0.5005 - val_f1_weighted: 0.6333
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.8025 - loss: 0.5005 - val_accuracy: 0.6177 - val_loss: 1.1520 - val_f1_weighted: 0.6333 - learning_rate: 2.4000e-06
# Epoch 104/200
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8082 - loss: 0.5143 - val_f1_weighted: 0.6341
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.8082 - loss: 0.5143 - val_accuracy: 0.6197 - val_loss: 1.1436 - val_f1_weighted: 0.6341 - learning_rate: 2.4000e-06
# Epoch 105/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8058 - loss: 0.4852 - val_f1_weighted: 0.6270
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.8058 - loss: 0.4853 - val_accuracy: 0.6091 - val_loss: 1.1583 - val_f1_weighted: 0.6270 - learning_rate: 2.4000e-06
# Epoch 106/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7913 - loss: 0.4468 - val_f1_weighted: 0.6333
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7913 - loss: 0.4468 - val_accuracy: 0.6217 - val_loss: 1.1403 - val_f1_weighted: 0.6333 - learning_rate: 2.4000e-06
# Epoch 107/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8043 - loss: 0.4844 - val_f1_weighted: 0.6288
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.8044 - loss: 0.4843 - val_accuracy: 0.6210 - val_loss: 1.1232 - val_f1_weighted: 0.6288 - learning_rate: 2.4000e-06
# Epoch 108/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8065 - loss: 0.4532 - val_f1_weighted: 0.6293
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.8065 - loss: 0.4532 - val_accuracy: 0.6138 - val_loss: 1.1555 - val_f1_weighted: 0.6293 - learning_rate: 2.4000e-06
# Epoch 109/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8112 - loss: 0.4483 - val_f1_weighted: 0.6332
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.8112 - loss: 0.4483 - val_accuracy: 0.6217 - val_loss: 1.1288 - val_f1_weighted: 0.6332 - learning_rate: 2.4000e-06
# Epoch 110/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8014 - loss: 0.4983 - val_f1_weighted: 0.6296
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.8015 - loss: 0.4983 - val_accuracy: 0.6151 - val_loss: 1.1499 - val_f1_weighted: 0.6296 - learning_rate: 2.4000e-06
# Epoch 111/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8086 - loss: 0.4757 - val_f1_weighted: 0.6318
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.8085 - loss: 0.4757 - val_accuracy: 0.6197 - val_loss: 1.1274 - val_f1_weighted: 0.6318 - learning_rate: 2.4000e-06
# Epoch 112/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8070 - loss: 0.4973 - val_f1_weighted: 0.6296
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.8071 - loss: 0.4973 - val_accuracy: 0.6131 - val_loss: 1.1610 - val_f1_weighted: 0.6296 - learning_rate: 2.4000e-06
# Epoch 113/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7995 - loss: 0.4731 - val_f1_weighted: 0.6357
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7995 - loss: 0.4731 - val_accuracy: 0.6224 - val_loss: 1.1409 - val_f1_weighted: 0.6357 - learning_rate: 2.4000e-06
# Epoch 114/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8130 - loss: 0.4497 - val_f1_weighted: 0.6321
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.8130 - loss: 0.4497 - val_accuracy: 0.6217 - val_loss: 1.1317 - val_f1_weighted: 0.6321 - learning_rate: 2.4000e-06
# Epoch 115/200
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8136 - loss: 0.4547 - val_f1_weighted: 0.6322
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.8135 - loss: 0.4547 - val_accuracy: 0.6171 - val_loss: 1.1479 - val_f1_weighted: 0.6322 - learning_rate: 2.4000e-06
# Epoch 116/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8152 - loss: 0.4632 - val_f1_weighted: 0.6258
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.8152 - loss: 0.4632 - val_accuracy: 0.6065 - val_loss: 1.1621 - val_f1_weighted: 0.6258 - learning_rate: 2.4000e-06
# Epoch 117/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8130 - loss: 0.4946 - val_f1_weighted: 0.6295
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.8130 - loss: 0.4946 - val_accuracy: 0.6138 - val_loss: 1.1486 - val_f1_weighted: 0.6295 - learning_rate: 2.4000e-06
# Epoch 118/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8007 - loss: 0.4968 - val_f1_weighted: 0.6323
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.8007 - loss: 0.4968 - val_accuracy: 0.6157 - val_loss: 1.1495 - val_f1_weighted: 0.6323 - learning_rate: 2.4000e-06
# Epoch 119/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8094 - loss: 0.5254 - val_f1_weighted: 0.6297
#
# Epoch 119: ReduceLROnPlateau reducing learning rate to 1e-06.
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.8094 - loss: 0.5254 - val_accuracy: 0.6138 - val_loss: 1.1571 - val_f1_weighted: 0.6297 - learning_rate: 2.4000e-06
# Epoch 120/200
# 625/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7984 - loss: 0.4907 - val_f1_weighted: 0.6332
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7984 - loss: 0.4907 - val_accuracy: 0.6184 - val_loss: 1.1482 - val_f1_weighted: 0.6332 - learning_rate: 1.0000e-06
# Epoch 121/200
# 624/626 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8143 - loss: 0.4834 - val_f1_weighted: 0.6312
# Early stopping triggered based on weighted F1-score.
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.8142 - loss: 0.4835 - val_accuracy: 0.6144 - val_loss: 1.1539 - val_f1_weighted: 0.6312 - learning_rate: 1.0000e-06
#
# --- Training Finished ---

# %% [markdown]
# ## **Evaluation**

# %%
# ==============================================================================
# BLOCK 5: EVALUATION
# ==============================================================================

print("\n\n--- Final Evaluation on Test Set ---")
try:
    print(f"Loading best model from: {CLASSIFIER_MODEL_PATH}")
    best_model = models.load_model(
        CLASSIFIER_MODEL_PATH,
        custom_objects={'SpectralFilterLayer': SpectralFilterLayer}
    )

    # --- 1. Evaluating Loss and Accuracy ---
    print("\n--- Calculating Loss and Accuracy on Test Set ---")
    loss, accuracy = best_model.evaluate(X_test, y_test, verbose=0)
    print(f"Test Loss:      {loss:.4f}")
    print(f"Test Accuracy:  {accuracy:.4f}")

    # --- 2. Getting Predictions ---
    y_pred_proba = best_model.predict(X_test)
    y_pred_classes = np.argmax(y_pred_proba, axis=1)

    # --- 3. Detailed Metrics ---
    print("\n--- Detailed Performance Metrics ---")
    macro_f1 = f1_score(y_test, y_pred_classes, average='macro')
    weighted_f1 = f1_score(y_test, y_pred_classes, average='weighted')
    print(f"Macro F1 Score:   {macro_f1:.4f}")
    print(f"Weighted F1 Score:{weighted_f1:.4f}")

    kappa = cohen_kappa_score(y_test, y_pred_classes)
    mcc = matthews_corrcoef(y_test, y_pred_classes)
    print(f"Cohen's Kappa:    {kappa:.4f}")
    print(f"MCC:              {mcc:.4f}")

    auc_roc = roc_auc_score(y_test, y_pred_proba, multi_class='ovr', average='macro')
    print(f"AUC-ROC (Macro):  {auc_roc:.4f}")
    weighted_auc_roc = roc_auc_score(y_test, y_pred_proba, multi_class='ovr', average='weighted')
    print(f"AUC-ROC (Weighted):  {weighted_auc_roc:.4f}")

    # --- 4. Classification Report ---
    print("\n--- Classification Report ---")
    print(classification_report(y_test, y_pred_classes, target_names=CLASS_NAMES, digits=4))

    # --- 5. Confusion Matrix ---
    cm = confusion_matrix(y_test, y_pred_classes)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES)
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    # plt.title('SpectraNet-1 on HAM10000')
    plt.show()

    # --- 6. Plotting Training History ---
    print("\n--- Training History Plots ---")
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6))
    ax1.plot(history.history['loss'], label='Train Loss')
    ax1.plot(history.history['val_loss'], label='Val Loss')
    ax1.set_title('Model Loss')
    ax1.set_xlabel('Epoch')
    ax1.legend()
    ax1.grid(True)
    ax2.plot(history.history['accuracy'], label='Train Accuracy')
    ax2.plot(history.history['val_accuracy'], label='Val Accuracy')
    if 'val_f1_weighted' in history.history:
        ax2.plot(history.history['val_f1_weighted'], label='Validation F1 (Weighted)', linestyle='--')
    ax2.set_title('Model Performance')
    ax2.set_xlabel('Epoch')
    ax2.legend()
    ax2.grid(True)
    plt.show()

    # --- 7. ROC Curve Plot ---
    print("\n--- ROC Curve Analysis ---")
    y_test_binarized = label_binarize(y_test, classes=range(len(CLASS_NAMES)))
    n_classes = y_test_binarized.shape[1]
    fpr, tpr, roc_auc_dict = dict(), dict(), dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test_binarized[:, i], y_pred_proba[:, i])
        roc_auc_dict[i] = auc(fpr[i], tpr[i])
    plt.figure(figsize=(10, 8))
    colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'red', 'green', 'purple', 'brown'])
    for i, color in zip(range(n_classes), colors):
        plt.plot(fpr[i], tpr[i], color=color, lw=2,
                 label=f'ROC curve of class {CLASS_NAMES[i]} (area = {roc_auc_dict[i]:.2f})')
    plt.plot([0, 1], [0, 1], 'k--', lw=2)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Multi-Class Receiver Operating Characteristic (ROC)')
    plt.legend(loc="lower right")
    plt.grid(True)
    plt.show()

except Exception as e:
    print(f"An error occurred during evaluation: {e}")

print("\n--- Script Finished ---")
# Out:
# --- Final Evaluation on Unseen Test Set ---
# Loading best model from: /content/drive/MyDrive/S2F_Net_Models/SpectralNet_1SC_HAM10000.keras
#
# --- Calculating Loss and Accuracy on Test Set ---
# Test Loss:      1.1092
# Test Accuracy:  0.6310
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step
#
# --- Detailed Performance Metrics ---
# Macro F1 Score:   0.4378
# Weighted F1 Score:0.6408
# Cohen's Kappa:    0.4059
# MCC:              0.4074
# AUC-ROC (Macro):  0.8232
# AUC-ROC (Weighted):  0.8324
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#          MEL     0.3504    0.4795    0.4049       171
#           NV     0.8377    0.7778    0.8066       909
#          BCC     0.3789    0.3871    0.3830        93
#        AKIEC     0.3462    0.4186    0.3789        43
#          BKL     0.4216    0.3963    0.4086       217
#           DF     0.1897    0.2500    0.2157        44
#         VASC     0.5600    0.4000    0.4667        35
#
#     accuracy                         0.6310      1512
#    macro avg     0.4406    0.4442    0.4378      1512
# weighted avg     0.6554    0.6310    0.6408      1512
# --- Training History Plots ---
# --- ROC Curve Analysis ---
# --- Script Finished ---
