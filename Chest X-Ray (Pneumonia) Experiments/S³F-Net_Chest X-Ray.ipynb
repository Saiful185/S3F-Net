# %% [markdown]
# # **Spatial-Spectral Summarizer Fusion Network (S³F-Net)**

# %% [markdown]
# This notebook contains the full implementation of **S³F-Net** on the Chest X-ray Pneumonia dataset. We use the **SpectraNet-1** variant as the spectral encoder here, and use simple **Concatenation Fusion** to fuse the two branches (Spatial & Spectral). The full architecture is customizable, feel free to do so. Edit the file paths according to your setup.

# %% [markdown]
# ## **Data Preparation**

# %%
# ==============================================================================
# BLOCK 1: SETUP, IMPORTS AND DATA LOADING (FOR CHEST X-RAY)
# ==============================================================================
import os
import cv2
import zipfile
import numpy as np
import tensorflow as tf
from google.colab import drive
from tensorflow.keras import layers, models, optimizers, callbacks
from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score, cohen_kappa_score, matthews_corrcoef, roc_auc_score, roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns

# --- Setup ---
print("--- Mounting Google Drive ---")
drive.mount('/content/drive')

# --- Configuration ---
# Aspect ratio for 1600x1200 (4:3) scaled to a width of 512
IMG_SIZE = (384, 512)
BATCH_SIZE = 16
EPOCHS = 100
RANDOM_STATE = 42

# --- Paths ---
ZIP_PATH = "/content/drive/MyDrive/Medical Image Segmentation/chest_xray.zip"
TEMP_DATA_DIR = "/content/chest_xray_temp"

# Unzipping the data
if not os.path.exists(TEMP_DATA_DIR):
    print(f"\n--- Unzipping dataset to local runtime... ---")
    with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
        zip_ref.extractall(TEMP_DATA_DIR)
    print("\n--- Unzipping complete! ---")
else:
    print("\n--- Dataset already unzipped. ---")

DATASET_BASE_PATH = os.path.join(TEMP_DATA_DIR, "chest_xray")
SAVE_FOLDER = "/content/drive/MyDrive/S3F_Net_Models"
os.makedirs(SAVE_FOLDER, exist_ok=True)
# Out:
# --- Mounting Google Drive ---
# Mounted at /content/drive
#
# --- Unzipping dataset to local runtime... ---
#
# --- Unzipping complete! ---

# %%
# ==============================================================================
# 2. Data Loading (Adapted for the Chest-XRay Dataset structure)
# ==============================================================================

def load_xray_split(folder_path):
    """Loads images and labels from a folder with NORMAL/PNEUMONIA subdirectories."""
    images, labels = [], []
    # Ensuring PNEUMONIA is consistently mapped to 1 (the positive class)
    class_names = ['NORMAL', 'PNEUMONIA']
    class_map = {name: i for i, name in enumerate(class_names)}
    print(f"Loading data from: {folder_path} with classes {class_map}")

    for class_name in class_names:
        class_path = os.path.join(folder_path, class_name)
        if not os.path.isdir(class_path): continue
        for filename in os.listdir(class_path):
            if not filename.lower().endswith(('.jpeg', '.jpg', '.png')): continue
            img_path = os.path.join(class_path, filename)
            try:
                img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
                if img is None: continue
                img = cv2.resize(img, (IMG_SIZE[1], IMG_SIZE[0]), interpolation=cv2.INTER_AREA)
                img = img.astype('float32') / 255.0
                images.append(img[..., np.newaxis])
                labels.append(class_map[class_name])
            except Exception as e:
                print(f"Error loading {img_path}: {e}")

    indices = np.arange(len(images))
    np.random.shuffle(indices)
    return np.array(images)[indices], np.array(labels)[indices], class_names

try:
    TRAIN_PATH = os.path.join(DATASET_BASE_PATH, "train")
    TEST_PATH = os.path.join(DATASET_BASE_PATH, "test")

    X_train, y_train, CLASS_NAMES = load_xray_split(TRAIN_PATH)
    X_test, y_test, _ = load_xray_split(TEST_PATH)

    X_val, y_val = X_test, y_test

    print("\n--- Data Loading Summary ---")
    print(f"Training set:   {len(X_train)} samples")
    print(f"Validation/Test set: {len(X_val)} samples")

    #Computing Class Weights to address imbalance in data
    class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
    class_weights_dict = dict(enumerate(class_weights))
    print(f"Calculated class weights: {class_weights_dict}")

except Exception as e:
    print(f"An error occurred during data loading: {e}"); exit()
# Out:
# Loading data from: /content/chest_xray_temp/chest_xray/train with classes {'NORMAL': 0, 'PNEUMONIA': 1}
# Loading data from: /content/chest_xray_temp/chest_xray/test with classes {'NORMAL': 0, 'PNEUMONIA': 1}
#
# --- Data Loading Summary ---
# Training set:   5232 samples
# Validation/Test set: 624 samples
# Calculated class weights: {0: np.float64(1.939214232765011), 1: np.float64(0.6737058975019315)}

# %% [markdown]
# ## **S³F-Net (Concatenation-Fusion SN1 Variant) Model Building**

# %%
# ==============================================================================
# BLOCK 3: MODEL ARCHITECTURE (CONCATENATION FUSION FOR CHEST X-RAY)
# ==============================================================================
# This block defines the S³F-Net with SpectraNet-1 + Concatenation Fusion

# --- Custom SpectralFilter Layer & Encoders ---
class SpectralFilterLayer(layers.Layer):
    def __init__(self, filters, **kwargs): super().__init__(**kwargs); self.filters = filters
    def build(self, input_shape):
        _, h, w, c = input_shape
        fft_shape = (h, w // 2 + 1)
        self.real_weights = self.add_weight(name='real_weights', shape=(c, self.filters, *fft_shape), initializer='glorot_uniform')
        self.imag_weights = self.add_weight(name='imag_weights', shape=(c, self.filters, *fft_shape), initializer='glorot_uniform')
        self.bias = self.add_weight(name='bias', shape=(self.filters,), initializer='zeros')
    def call(self, inputs):
        inputs_p = tf.transpose(inputs, [0, 3, 1, 2])
        inputs_fft = tf.signal.rfft2d(inputs_p)
        kernel_fft = tf.complex(self.real_weights, self.imag_weights)
        output_fft = tf.einsum('bchw,cfhw->bfhw', inputs_fft, kernel_fft)
        output_s = tf.signal.irfft2d(output_fft)
        output_p = tf.transpose(output_s, [0, 2, 3, 1])
        return output_p + self.bias
    def get_config(self):
        config = super().get_config()
        config.update({"filters": self.filters})
        return config

def build_spatial_encoder(inputs):
    x = inputs
    x = layers.Conv2D(32, 3, padding='same', activation='relu')(x)
    x = layers.Conv2D(32, 3, padding='same')(x); x = layers.BatchNormalization()(x); x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D(2)(x)
    x = layers.Dropout(0.2)(x)
    x = layers.Conv2D(64, 3, padding='same', activation='relu')(x)
    x = layers.Conv2D(64, 3, padding='same')(x); x = layers.BatchNormalization()(x); x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D(2)(x)
    x = layers.Dropout(0.3)(x)
    x = layers.Conv2D(128, 3, padding='same', activation='relu')(x)
    x = layers.Conv2D(128, 3, padding='same')(x); x = layers.BatchNormalization()(x); x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D(2)(x)
    x = layers.Dropout(0.4)(x)
    x = layers.Conv2D(256, 3, padding='same', activation='relu')(x)
    x = layers.Conv2D(256, 3, padding='same')(x); x = layers.BatchNormalization()(x); x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D(2)(x)
    x = layers.Dropout(0.4)(x)
    return x

def depthwise_sep_block(x, filters, kernel_size=3, strides=1):
    x = layers.DepthwiseConv2D(kernel_size, strides=strides, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = layers.Conv2D(filters, 1, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    return x

def build_spectral_summary_branch(inputs):
    x = SpectralFilterLayer(32)(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = depthwise_sep_block(x, 64)
    x = layers.MaxPooling2D(2)(x)

    x = depthwise_sep_block(x, 128)
    x = layers.MaxPooling2D(2)(x)

    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(16, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.1875)(x)
    x = layers.Dense(4, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.3125)(x)

    return x

# --- S³F-Net Model Builder with Concatenation Fusion ---
def build_s3f_net_concatenation_binary(input_shape):
    """Builds the S³F-Net with Concatenation fusion for binary classification."""
    inputs = layers.Input(input_shape)

    # --- Tower 1: Deep Spatial Branch ---
    spatial_features = build_spatial_encoder(inputs)
    spatial_vector_raw = layers.GlobalAveragePooling2D()(spatial_features)
    spatial_refined = layers.Dense(512, activation='relu')(spatial_vector_raw)
    spatial_refined = layers.BatchNormalization()(spatial_refined)
    spatial_refined = layers.Dropout(0.5)(spatial_refined)

    # --- Tower 2: Spectral Summary Branch ---
    spectral_summary_vector = build_spectral_summary_branch(inputs)

    # --- Concatenation Fusion ---
    fused_vector = layers.concatenate([spatial_refined, spectral_summary_vector])

    # Output Layer
    outputs = layers.Dense(1, activation='sigmoid')(fused_vector)

    model = models.Model(inputs, outputs, name="S3F_Net_Concatenation_Binary")

    # Compiling with BCE loss
    model.compile(optimizer=optimizers.Adam(0.0003),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

print("Concatenation Fusion S³F-Net model architecture is ready for Chest X-Ray.")
# Out:
# Concatenation Fusion S3F-Net model architecture is ready for Chest X-Ray.

# %% [markdown]
# ## **Model Training**

# %%
# ===========================================
# BLOCK 4: CUSTOM CALLBACK AND TRAINING
# ===========================================

# --- Binary F1 Score Callback ---
class BinaryF1ScoreCallback(callbacks.Callback):
    def __init__(self, validation_data, filepath, patience=15):
        super(BinaryF1ScoreCallback, self).__init__()
        self.validation_data = validation_data
        self.filepath = filepath
        self.patience = patience
        self.best_f1 = -1.0
        self.wait = 0
    def on_epoch_end(self, epoch, logs=None):
        X_val, y_val = self.validation_data
        y_pred_proba = self.model.predict(X_val, verbose=0)
        y_pred = (y_pred_proba > 0.5).astype(int)
        f1 = f1_score(y_val, y_pred, pos_label=1, zero_division=0)
        logs['val_f1'] = f1
        print(f" - val_f1 (PNEUMONIA): {f1:.4f}", end="")
        if f1 > self.best_f1:
            print(f" (New best F1, saving model)")
            self.best_f1 = f1
            self.model.save(self.filepath)
            self.wait = 0
        else:
            print()
            self.wait += 1
            if self.wait >= self.patience:
                print("Early stopping.")
                self.model.stop_training = True

# --- Training ---
CLASSIFIER_MODEL_PATH = os.path.join(SAVE_FOLDER, "Concatenation_S3f_net_SN1_XRAY.keras")
print("\n--- Building Concatenation Fusion S³F-Net for Chest X-Ray ---")
classifier_model_concat = build_s3f_net_concatenation_binary(X_train.shape[1:])
classifier_model_concat.summary()

f1_callback_concat = BinaryF1ScoreCallback(validation_data=(X_val, y_val), filepath=CLASSIFIER_MODEL_PATH, patience=20)
reduce_lr_concat = callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=10, min_lr=1e-6)

history_concat = classifier_model_concat.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    class_weight=class_weights_dict,
    callbacks=[f1_callback_concat, reduce_lr_concat]
)

print("\n--- Training Finished ---")
# Out:
# --- Building Concatenation Fusion S3F-Net for Chest X-Ray ---
# Model: "S3F_Net_Concatenation_Binary"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4       │ (None, 384, 512,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 384, 512,  │        320 │ input_layer_4[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 384, 512,  │      9,248 │ conv2d_30[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 384, 512,  │        128 │ conv2d_31[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 384, 512,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_19    │ (None, 192, 256,  │          0 │ activation_12[0]… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spectral_conv_laye… │ (None, 384, 512,  │  6,316,064 │ input_layer_4[0]… │
# │ (SpectralConvLayer) │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_23          │ (None, 192, 256,  │          0 │ max_pooling2d_19… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 384, 512,  │        128 │ spectral_conv_la… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 192, 256,  │     18,496 │ dropout_23[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_18 (ReLU)     │ (None, 384, 512,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 192, 256,  │     36,928 │ conv2d_32[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_6  │ (None, 384, 512,  │        288 │ re_lu_18[0][0]    │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 192, 256,  │        256 │ conv2d_33[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 384, 512,  │        128 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 192, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_19 (ReLU)     │ (None, 384, 512,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_20    │ (None, 96, 128,   │          0 │ activation_13[0]… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_38 (Conv2D)  │ (None, 384, 512,  │      2,048 │ re_lu_19[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_24          │ (None, 96, 128,   │          0 │ max_pooling2d_20… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 384, 512,  │        256 │ conv2d_38[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 96, 128,   │     73,856 │ dropout_24[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_20 (ReLU)     │ (None, 384, 512,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 96, 128,   │    147,584 │ conv2d_34[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_23    │ (None, 192, 256,  │          0 │ re_lu_20[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 96, 128,   │        512 │ conv2d_35[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_7  │ (None, 192, 256,  │        576 │ max_pooling2d_23… │
# │ (DepthwiseConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 96, 128,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 192, 256,  │        256 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_21    │ (None, 48, 64,    │          0 │ activation_14[0]… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_21 (ReLU)     │ (None, 192, 256,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_25          │ (None, 48, 64,    │          0 │ max_pooling2d_21… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_39 (Conv2D)  │ (None, 192, 256,  │      8,192 │ re_lu_21[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 48, 64,    │    295,168 │ dropout_25[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 192, 256,  │        512 │ conv2d_39[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 48, 64,    │    590,080 │ conv2d_36[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_22 (ReLU)     │ (None, 192, 256,  │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 64,    │      1,024 │ conv2d_37[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_24    │ (None, 96, 128,   │          0 │ re_lu_22[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 48, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ max_pooling2d_24… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_22    │ (None, 24, 32,    │          0 │ activation_15[0]… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 16)        │      2,064 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_26          │ (None, 24, 32,    │          0 │ max_pooling2d_22… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16)        │         64 │ dense_16[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ dropout_26[0][0]  │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_28          │ (None, 16)        │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 512)       │    131,584 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 4)         │         68 │ dropout_28[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ dense_15[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4)         │         16 │ dense_17[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_27          │ (None, 512)       │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_29          │ (None, 4)         │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 516)       │          0 │ dropout_27[0][0], │
# │ (Concatenate)       │                   │            │ dropout_29[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 1)         │        517 │ concatenate_3[0]… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,638,409 (29.14 MB)
#  Trainable params: 7,635,745 (29.13 MB)
#  Non-trainable params: 2,664 (10.41 KB)
# Epoch 1/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7284 - loss: 0.5146 - val_f1 (PNEUMONIA): 0.7692 (New best F1, saving model)
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 62s 122ms/step - accuracy: 0.7286 - loss: 0.5143 - val_accuracy: 0.6250 - val_loss: 1.5595 - val_f1: 0.7692 - learning_rate: 3.0000e-04
# Epoch 2/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8875 - loss: 0.2816 - val_f1 (PNEUMONIA): 0.7746 (New best F1, saving model)
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 99ms/step - accuracy: 0.8875 - loss: 0.2816 - val_accuracy: 0.6362 - val_loss: 1.4833 - val_f1: 0.7746 - learning_rate: 3.0000e-04
# Epoch 3/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9122 - loss: 0.2088 - val_f1 (PNEUMONIA): 0.6056
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9123 - loss: 0.2088 - val_accuracy: 0.6410 - val_loss: 1.0361 - val_f1: 0.6056 - learning_rate: 3.0000e-04
# Epoch 4/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9365 - loss: 0.1575 - val_f1 (PNEUMONIA): 0.8159 (New best F1, saving model)
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 99ms/step - accuracy: 0.9365 - loss: 0.1575 - val_accuracy: 0.7196 - val_loss: 0.6561 - val_f1: 0.8159 - learning_rate: 3.0000e-04
# Epoch 5/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9445 - loss: 0.1335 - val_f1 (PNEUMONIA): 0.7692
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9445 - loss: 0.1335 - val_accuracy: 0.6250 - val_loss: 4.6115 - val_f1: 0.7692 - learning_rate: 3.0000e-04
# Epoch 6/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9514 - loss: 0.1184 - val_f1 (PNEUMONIA): 0.8037
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9515 - loss: 0.1183 - val_accuracy: 0.7933 - val_loss: 0.5453 - val_f1: 0.8037 - learning_rate: 3.0000e-04
# Epoch 7/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9622 - loss: 0.1002 - val_f1 (PNEUMONIA): 0.7847
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9622 - loss: 0.1002 - val_accuracy: 0.6571 - val_loss: 1.1650 - val_f1: 0.7847 - learning_rate: 3.0000e-04
# Epoch 8/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9710 - loss: 0.0740 - val_f1 (PNEUMONIA): 0.7692
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9710 - loss: 0.0740 - val_accuracy: 0.6250 - val_loss: 3.3363 - val_f1: 0.7692 - learning_rate: 3.0000e-04
# Epoch 9/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9776 - loss: 0.0653 - val_f1 (PNEUMONIA): 0.7708
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9776 - loss: 0.0653 - val_accuracy: 0.6282 - val_loss: 2.6941 - val_f1: 0.7708 - learning_rate: 3.0000e-04
# Epoch 10/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9872 - loss: 0.0383 - val_f1 (PNEUMONIA): 0.9057 (New best F1, saving model)
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 99ms/step - accuracy: 0.9872 - loss: 0.0384 - val_accuracy: 0.8862 - val_loss: 0.2730 - val_f1: 0.9057 - learning_rate: 3.0000e-04
# Epoch 11/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9851 - loss: 0.0437 - val_f1 (PNEUMONIA): 0.2550
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9851 - loss: 0.0437 - val_accuracy: 0.4663 - val_loss: 2.6894 - val_f1: 0.2550 - learning_rate: 3.0000e-04
# Epoch 12/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9814 - loss: 0.0505 - val_f1 (PNEUMONIA): 0.4528
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9814 - loss: 0.0505 - val_accuracy: 0.5545 - val_loss: 1.2039 - val_f1: 0.4528 - learning_rate: 3.0000e-04
# Epoch 13/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9905 - loss: 0.0320 - val_f1 (PNEUMONIA): 0.8237
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9905 - loss: 0.0320 - val_accuracy: 0.7324 - val_loss: 1.2316 - val_f1: 0.8237 - learning_rate: 3.0000e-04
# Epoch 14/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9896 - loss: 0.0325 - val_f1 (PNEUMONIA): 0.7708
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9896 - loss: 0.0325 - val_accuracy: 0.6282 - val_loss: 6.2025 - val_f1: 0.7708 - learning_rate: 3.0000e-04
# Epoch 15/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9899 - loss: 0.0297 - val_f1 (PNEUMONIA): 0.9326 (New best F1, saving model)
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 99ms/step - accuracy: 0.9899 - loss: 0.0298 - val_accuracy: 0.9167 - val_loss: 0.2116 - val_f1: 0.9326 - learning_rate: 3.0000e-04
# Epoch 16/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9856 - loss: 0.0382 - val_f1 (PNEUMONIA): 0.7700
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9856 - loss: 0.0382 - val_accuracy: 0.6266 - val_loss: 3.1875 - val_f1: 0.7700 - learning_rate: 3.0000e-04
# Epoch 17/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9854 - loss: 0.0416 - val_f1 (PNEUMONIA): 0.9302
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9854 - loss: 0.0416 - val_accuracy: 0.9151 - val_loss: 0.2373 - val_f1: 0.9302 - learning_rate: 3.0000e-04
# Epoch 18/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9896 - loss: 0.0299 - val_f1 (PNEUMONIA): 0.7700
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9896 - loss: 0.0298 - val_accuracy: 0.6266 - val_loss: 5.2618 - val_f1: 0.7700 - learning_rate: 3.0000e-04
# Epoch 19/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9950 - loss: 0.0202 - val_f1 (PNEUMONIA): 0.9400 (New best F1, saving model)
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 99ms/step - accuracy: 0.9950 - loss: 0.0202 - val_accuracy: 0.9231 - val_loss: 0.1853 - val_f1: 0.9400 - learning_rate: 3.0000e-04
# Epoch 20/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9963 - loss: 0.0141 - val_f1 (PNEUMONIA): 0.7715
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9963 - loss: 0.0141 - val_accuracy: 0.6298 - val_loss: 4.1992 - val_f1: 0.7715 - learning_rate: 3.0000e-04
# Epoch 21/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9942 - loss: 0.0206 - val_f1 (PNEUMONIA): 0.7903
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9942 - loss: 0.0206 - val_accuracy: 0.6683 - val_loss: 2.2903 - val_f1: 0.7903 - learning_rate: 3.0000e-04
# Epoch 22/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9819 - loss: 0.0409 - val_f1 (PNEUMONIA): 0.2494
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9819 - loss: 0.0409 - val_accuracy: 0.4599 - val_loss: 3.6583 - val_f1: 0.2494 - learning_rate: 3.0000e-04
# Epoch 23/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9822 - loss: 0.0434 - val_f1 (PNEUMONIA): 0.9515 (New best F1, saving model)
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 99ms/step - accuracy: 0.9823 - loss: 0.0434 - val_accuracy: 0.9391 - val_loss: 0.1743 - val_f1: 0.9515 - learning_rate: 3.0000e-04
# Epoch 24/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9950 - loss: 0.0179 - val_f1 (PNEUMONIA): 0.9117
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9949 - loss: 0.0179 - val_accuracy: 0.8798 - val_loss: 0.3604 - val_f1: 0.9117 - learning_rate: 3.0000e-04
# Epoch 25/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9966 - loss: 0.0128 - val_f1 (PNEUMONIA): 0.8964
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9966 - loss: 0.0128 - val_accuracy: 0.8574 - val_loss: 0.4391 - val_f1: 0.8964 - learning_rate: 3.0000e-04
# Epoch 26/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9926 - loss: 0.0211 - val_f1 (PNEUMONIA): 0.7784
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9926 - loss: 0.0210 - val_accuracy: 0.6442 - val_loss: 3.6961 - val_f1: 0.7784 - learning_rate: 3.0000e-04
# Epoch 27/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9891 - loss: 0.0354 - val_f1 (PNEUMONIA): 0.8333
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9891 - loss: 0.0354 - val_accuracy: 0.7500 - val_loss: 1.6707 - val_f1: 0.8333 - learning_rate: 3.0000e-04
# Epoch 28/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9870 - loss: 0.0302 - val_f1 (PNEUMONIA): 0.7715
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9870 - loss: 0.0302 - val_accuracy: 0.6298 - val_loss: 3.9772 - val_f1: 0.7715 - learning_rate: 3.0000e-04
# Epoch 29/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9930 - loss: 0.0192 - val_f1 (PNEUMONIA): 0.7746
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9930 - loss: 0.0192 - val_accuracy: 0.6362 - val_loss: 4.7430 - val_f1: 0.7746 - learning_rate: 3.0000e-04
# Epoch 30/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9932 - loss: 0.0219 - val_f1 (PNEUMONIA): 0.9292
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9932 - loss: 0.0218 - val_accuracy: 0.9054 - val_loss: 0.2791 - val_f1: 0.9292 - learning_rate: 3.0000e-04
# Epoch 31/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9944 - loss: 0.0139 - val_f1 (PNEUMONIA): 0.9364
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9944 - loss: 0.0139 - val_accuracy: 0.9167 - val_loss: 0.2377 - val_f1: 0.9364 - learning_rate: 3.0000e-04
# Epoch 32/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9929 - loss: 0.0193 - val_f1 (PNEUMONIA): 0.8225
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9929 - loss: 0.0193 - val_accuracy: 0.8029 - val_loss: 0.5490 - val_f1: 0.8225 - learning_rate: 3.0000e-04
# Epoch 33/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9958 - loss: 0.0103 - val_f1 (PNEUMONIA): 0.7769
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9958 - loss: 0.0103 - val_accuracy: 0.6410 - val_loss: 3.8670 - val_f1: 0.7769 - learning_rate: 3.0000e-04
# Epoch 34/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9975 - loss: 0.0087 - val_f1 (PNEUMONIA): 0.8955
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9975 - loss: 0.0087 - val_accuracy: 0.8542 - val_loss: 0.6763 - val_f1: 0.8955 - learning_rate: 6.0000e-05
# Epoch 35/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9978 - loss: 0.0065 - val_f1 (PNEUMONIA): 0.9511
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9978 - loss: 0.0065 - val_accuracy: 0.9375 - val_loss: 0.2030 - val_f1: 0.9511 - learning_rate: 6.0000e-05
# Epoch 36/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9975 - loss: 0.0065 - val_f1 (PNEUMONIA): 0.8924
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9975 - loss: 0.0065 - val_accuracy: 0.8494 - val_loss: 0.6781 - val_f1: 0.8924 - learning_rate: 6.0000e-05
# Epoch 37/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9981 - loss: 0.0057 - val_f1 (PNEUMONIA): 0.8912
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9981 - loss: 0.0057 - val_accuracy: 0.8478 - val_loss: 0.6816 - val_f1: 0.8912 - learning_rate: 6.0000e-05
# Epoch 38/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9976 - loss: 0.0069 - val_f1 (PNEUMONIA): 0.8534
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9976 - loss: 0.0069 - val_accuracy: 0.7853 - val_loss: 1.2073 - val_f1: 0.8534 - learning_rate: 6.0000e-05
# Epoch 39/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9966 - loss: 0.0084 - val_f1 (PNEUMONIA): 0.7800
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9966 - loss: 0.0084 - val_accuracy: 0.6474 - val_loss: 3.8505 - val_f1: 0.7800 - learning_rate: 6.0000e-05
# Epoch 40/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9967 - loss: 0.0086 - val_f1 (PNEUMONIA): 0.8245
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9967 - loss: 0.0086 - val_accuracy: 0.7340 - val_loss: 1.7094 - val_f1: 0.8245 - learning_rate: 6.0000e-05
# Epoch 41/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9975 - loss: 0.0086 - val_f1 (PNEUMONIA): 0.8342
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9975 - loss: 0.0086 - val_accuracy: 0.7516 - val_loss: 1.4454 - val_f1: 0.8342 - learning_rate: 6.0000e-05
# Epoch 42/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9987 - loss: 0.0044 - val_f1 (PNEUMONIA): 0.8725
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9987 - loss: 0.0044 - val_accuracy: 0.8173 - val_loss: 0.8526 - val_f1: 0.8725 - learning_rate: 6.0000e-05
# Epoch 43/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9989 - loss: 0.0055 - val_f1 (PNEUMONIA): 0.9275
# Early stopping.
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 97ms/step - accuracy: 0.9989 - loss: 0.0055 - val_accuracy: 0.9038 - val_loss: 0.3435 - val_f1: 0.9275 - learning_rate: 6.0000e-05
#
# --- Training Finished ---

# %% [markdown]
# ## **Evaluation**

# %%
# ======================
# BLOCK 5: EVALUATION
# ======================
print("\n\n--- Final Evaluation on Chest X-Ray Test Set ---")
CLASSIFIER_MODEL_PATH = os.path.join(SAVE_FOLDER, "Concatenation_S3f_net_SN1_XRAY.keras")
custom_objects = {'SpectralFilterLayer': SpectralFilterLayer}
try:
    print(f"Loading best model from: {CLASSIFIER_MODEL_PATH}")
    best_model = models.load_model(CLASSIFIER_MODEL_PATH, custom_objects=custom_objects)

    loss, accuracy = best_model.evaluate(X_test, y_test, verbose=0)
    print(f"\nTest Loss: {loss:.4f}"); print(f"Test Accuracy: {accuracy:.4f}")

    y_pred_proba = best_model.predict(X_test)
    y_pred_classes = (y_pred_proba > 0.5).astype(int)

    print("\n--- Detailed Performance Metrics ---")
    f1_pneumonia = f1_score(y_test, y_pred_classes, pos_label=1)
    print(f"F1 Score (Pneumonia): {f1_pneumonia:.4f}")
    print(f"Cohen's Kappa: {cohen_kappa_score(y_test, y_pred_classes):.4f}")
    print(f"MCC: {matthews_corrcoef(y_test, y_pred_classes):.4f}")
    print(f"AUC-ROC: {roc_auc_score(y_test, y_pred_proba):.4f}")

    print("\n--- Classification Report ---")
    print(classification_report(y_test, y_pred_classes, target_names=CLASS_NAMES, digits=4))

    print("\n--- Confusion Matrix ---")
    cm = confusion_matrix(y_test, y_pred_classes)
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES)
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    # plt.title('S³F-Net on Chest X-Ray (Test Set)')
    plt.show()

    if 'history' in locals():
        print("\n--- Training History Plots ---")
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6))
        ax1.plot(history_concat.history['loss'], label='Train Loss')
        ax1.plot(history_concat.history['val_loss'], label='Val Loss')
        # ax1.set_title('Model Loss')
        ax1.legend()
        ax1.grid(True)
        ax2.plot(history_concat.history['accuracy'], label='Train Accuracy')
        ax2.plot(history_concat.history['val_accuracy'], label='Val Accuracy')
        if 'val_f1' in history_concat.history:
            ax2.plot(history_concat.history['val_f1'], label='Validation F1', linestyle='--')
        # ax2.set_title('Model Performance')
        ax2.legend()
        ax2.grid(True)
        plt.show()

    print("\n--- ROC Curve Analysis ---")
    fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
    roc_auc = auc(fpr, tpr)
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.4f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--');
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    # plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc="lower right")
    plt.grid(True)
    plt.show()

except Exception as e:
    print(f"An error occurred during evaluation: {e}")
# Out:
# --- Final Evaluation on Chest X-Ray Test Set ---
# Loading best model from: /content/drive/MyDrive/S2F_Net_Models/Concatenation_S3f_net_SN1_XRAY.keras
#
# Test Loss: 0.1743
# Test Accuracy: 0.9391
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step
#
# --- Detailed Performance Metrics ---
# F1 Score (Pneumonia): 0.9515
# Cohen's Kappa: 0.8696
# MCC: 0.8697
# AUC-ROC: 0.9821
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#       NORMAL     0.9261    0.9103    0.9181       234
#    PNEUMONIA     0.9467    0.9564    0.9515       390
#
#     accuracy                         0.9391       624
#    macro avg     0.9364    0.9333    0.9348       624
# weighted avg     0.9390    0.9391    0.9390       624
#
#
# --- Confusion Matrix ---
# --- ROC Curve Analysis ---
